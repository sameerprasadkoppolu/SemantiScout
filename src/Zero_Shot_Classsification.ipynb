# %%
# !pip install transformers
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.44.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.16.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.24.7)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2024.9.11)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.5)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.19.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.5)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (2024.6.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.8.30)

# %%
queries_with_categories = [
    {"query": "I need a phone with a really good camera for under $500.", "category": "Electronics"},
    {"query": "What’s the best wireless headset for working from home?", "category": "Electronics"},
    {"query": "Can you suggest a smartwatch that works with iPhones?", "category": "Electronics"},
    {"query": "I’m looking for a TV that has both 4K and Dolby Vision support.", "category": "Electronics"},

    {"query": "I want a set of non-stick pans that last long and are easy to clean.", "category": "Home & Kitchen"},
    {"query": "What’s the best air purifier to help with allergies?", "category": "Home & Kitchen"},
    {"query": "I’m looking for a vacuum cleaner that works well for picking up pet hair.", "category": "Home & Kitchen"},
    {"query": "Can you recommend a fridge that’s energy-efficient and has smart features?", "category": "Home & Kitchen"},

    {"query": "I want a blue dress for summer that’s comfortable.", "category": "Fashion & Apparel"},
    {"query": "Can you help me find waterproof hiking boots for men?", "category": "Fashion & Apparel"},
    {"query": "I’m looking for a warm jacket for winter that isn’t too bulky.", "category": "Fashion & Apparel"},
    {"query": "I need a casual handbag made of leather, but not too expensive.", "category": "Fashion & Apparel"},

    {"query": "Can you recommend organic skincare for sensitive skin?", "category": "Health & Personal Care"},
    {"query": "I need an electric toothbrush that has a really long battery life.", "category": "Health & Personal Care"},
    {"query": "What’s the best hair dryer that works well for frizzy hair?", "category": "Health & Personal Care"},
    {"query": "I’m looking for vegan multivitamins that are good for daily use.", "category": "Health & Personal Care"},

    {"query": "I need a matte lipstick that lasts all day.", "category": "Beauty"},
    {"query": "Can you recommend a good anti-aging serum?", "category": "Beauty"},
    {"query": "I’m looking for a waterproof eyeliner that won’t smudge easily.", "category": "Beauty"},
    {"query": "What’s a good fragrance for summer that’s light and fresh?", "category": "Beauty"},

    {"query": "I want a lightweight tent for camping with my family.", "category": "Sports & Outdoors"},
    {"query": "What’s a good mountain bike for a beginner?", "category": "Sports & Outdoors"},
    {"query": "Can you recommend a yoga mat that’s comfortable for home workouts?", "category": "Sports & Outdoors"},
    {"query": "I need a backpack that’s waterproof and great for hiking.", "category": "Sports & Outdoors"},

    {"query": "I’m looking for an educational toy for my 5-year-old.", "category": "Toys & Games"},
    {"query": "What’s a good board game for playing with the whole family?", "category": "Toys & Games"},
    {"query": "My son loves remote control cars. Any recommendations?", "category": "Toys & Games"},
    {"query": "I need some fun water toys for my kids to play with outside this summer.", "category": "Toys & Games"},

    {"query": "Can you recommend a good thriller with a female lead?", "category": "Books"},
    {"query": "What’s a good book about productivity?", "category": "Books"},
    {"query": "I’m looking for a fantasy series for young adults. Any suggestions?", "category": "Books"},
    {"query": "Can you recommend a picture book with animals for kids?", "category": "Books"},

    {"query": "I need a cordless drill for some DIY projects around the house.", "category": "Tools & Home Improvement"},
    {"query": "What’s a good smart thermostat that will help save on energy?", "category": "Tools & Home Improvement"},
    {"query": "I’m looking for power tools for woodwork. Any recommendations?", "category": "Tools & Home Improvement"},
    {"query": "I want solar-powered lights for my garden.", "category": "Tools & Home Improvement"},

    {"query": "Can you recommend some gluten-free snacks for kids?", "category": "Grocery"},
    {"query": "I need keto-friendly ingredients for baking at home.", "category": "Grocery"},
    {"query": "What’s the best organic coffee for brewing at home?", "category": "Grocery"},
    {"query": "What are some good dairy-free milk alternatives?", "category": "Grocery"}
]

# %%
candidate_labels = [
    'Electronics',
    'Home & Kitchen',
    'Fashion & Apparel',
    'Health & Personal Care',
    'Beauty',
    'Sports & Outdoors',
    'Toys & Games',
    'Books',
    'Tools & Home Improvement',
    'Grocery'
]

# %%
import timeit
from sklearn.metrics import accuracy_score, precision_recall_fscore_support

# Function to run the classifier and return results for each query
def run_classification(queries_with_categories, candidate_labels, classifier):
    results_list = []
    total_time = 0  # To store the total execution time for all queries

    for test in queries_with_categories:
        # Start timing for the current query
        start_time = timeit.default_timer()

        # Run the classifier
        results = classifier(test['query'], candidate_labels)

        # End timing for the current query
        end_time = timeit.default_timer()

        # Calculate the time taken for the query
        time_taken = end_time - start_time
        total_time += time_taken  # Accumulate the time for each query

        results_list.append({
            "query": test['query'],
            "original_category": test['category'],
            "predicted_labels": results['labels'],
            "predicted_scores": results['scores'],
            "time_taken": time_taken  # Storing the time taken for each query
        })

        # Print the results and time taken for each query (optional)
        print(f"Query: {test['query']}")
        print(f"Original Category: {test['category']}")
        print(f"Predicted Category: {results['labels']}")
        print(f"Predicted Scores: {results['scores']}")
        print(f"Time taken: {time_taken:.4f} seconds")
        print("-" * 80)
        print()

    # Calculate the average time
    average_time = total_time / len(queries_with_categories)
    print(f"Average Time per Query: {average_time:.4f} seconds")

    return results_list

# Function to evaluate the predictions
def evaluate_predictions(results_list):
    true_labels = []
    predicted_top1 = []
    predicted_top3 = []
    evaluation_metrics = []

    # Gather true labels and top predictions
    for result in results_list:
        true_labels.append(result['original_category'])
        predicted_top1.append(result['predicted_labels'][0])  # Top-1 predicted label
        predicted_top3.append(result['predicted_labels'][:3])  # Top-3 predicted labels

    # Calculate Top-1 Accuracy
    top1_accuracy = accuracy_score(true_labels, predicted_top1)
    evaluation_metrics.append(top1_accuracy)
    print(f"Top-1 Accuracy: {top1_accuracy:.4f}")

    # Calculate Top-3 Accuracy
    top3_correct = sum(1 for true_label, top3_predictions in zip(true_labels, predicted_top3) if true_label in top3_predictions)
    top3_accuracy = top3_correct / len(true_labels)
    evaluation_metrics.append(top3_correct)
    print(f"Top-3 Accuracy: {top3_accuracy:.4f}")

    # Calculate Precision, Recall, and F1-Score
    precision, recall, f1, _ = precision_recall_fscore_support(true_labels, predicted_top1, average='weighted')
    evaluation_metrics.append(precision)
    evaluation_metrics.append(recall)
    evaluation_metrics.append(f1)
    print(f"Precision: {precision:.4f}, Recall: {recall:.4f}, F1-Score: {f1:.4f}")

    return evaluation_metrics

# %% [markdown]
# # Zero Shot Classification with BART LARGE

# %%
from transformers import pipeline
classifier_bart = pipeline("zero-shot-classification",
                      model="facebook/bart-large-mnli")
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(

# %%
# Main function to run classification and evaluation
def main(queries_with_categories, candidate_labels, classifier):
    # Run the classification
    results = run_classification(queries_with_categories, candidate_labels, classifier)

    # Evaluate the predictions
    evaluation_metrics = evaluate_predictions(results)
    return evaluation_metrics

main(queries_with_categories, candidate_labels, classifier_bart)
# Out:
# Query: I need a phone with a really good camera for under $500.
# Original Category: Electronics
# Predicted Category: ['Electronics', 'Beauty', 'Home & Kitchen', 'Sports & Outdoors', 'Toys & Games', 'Health & Personal Care', 'Books', 'Tools & Home Improvement', 'Fashion & Apparel', 'Grocery']
# Predicted Scores: [0.4416484534740448, 0.11992223560810089, 0.10086075961589813, 0.09315022826194763, 0.058817245066165924, 0.04412177577614784, 0.040335334837436676, 0.035431548953056335, 0.0334584042429924, 0.03225397691130638]
# Time taken: 10.2930 seconds
# --------------------------------------------------------------------------------
#
# Query: What’s the best wireless headset for working from home?
# Original Category: Electronics
# Predicted Category: ['Home & Kitchen', 'Electronics', 'Beauty', 'Books', 'Sports & Outdoors', 'Health & Personal Care', 'Toys & Games', 'Fashion & Apparel', 'Grocery', 'Tools & Home Improvement']
# Predicted Scores: [0.1639995127916336, 0.1562432199716568, 0.13981063663959503, 0.09417712688446045, 0.09028994292020798, 0.08895309269428253, 0.07504155486822128, 0.06704770028591156, 0.06557135283946991, 0.058865852653980255]
# Time taken: 6.3000 seconds
# --------------------------------------------------------------------------------
#
# Query: Can you suggest a smartwatch that works with iPhones?
# Original Category: Electronics
# Predicted Category: ['Electronics', 'Home & Kitchen', 'Beauty', 'Health & Personal Care', 'Sports & Outdoors', 'Toys & Games', 'Tools & Home Improvement', 'Books', 'Fashion & Apparel', 'Grocery']
# Predicted Scores: [0.331045001745224, 0.1379111260175705, 0.1047666072845459, 0.09930673986673355, 0.0760153979063034, 0.06212997063994408, 0.052179235965013504, 0.0483805276453495, 0.04709467664361, 0.041170693933963776]
# Time taken: 4.7144 seconds
# --------------------------------------------------------------------------------
#
# Query: I’m looking for a TV that has both 4K and Dolby Vision support.
# Original Category: Electronics
# Predicted Category: ['Electronics', 'Beauty', 'Home & Kitchen', 'Sports & Outdoors', 'Grocery', 'Health & Personal Care', 'Books', 'Toys & Games', 'Fashion & Apparel', 'Tools & Home Improvement']
# Predicted Scores: [0.3284143805503845, 0.14650864899158478, 0.10964258015155792, 0.08155643194913864, 0.07860410213470459, 0.06780697405338287, 0.056982770562171936, 0.054034583270549774, 0.04113089665770531, 0.03531870245933533]
# Time taken: 9.5992 seconds
# --------------------------------------------------------------------------------
#
# Query: I want a set of non-stick pans that last long and are easy to clean.
# Original Category: Home & Kitchen
# Predicted Category: ['Home & Kitchen', 'Beauty', 'Health & Personal Care', 'Sports & Outdoors', 'Toys & Games', 'Electronics', 'Tools & Home Improvement', 'Grocery', 'Books', 'Fashion & Apparel']
# Predicted Scores: [0.3629224896430969, 0.10694701969623566, 0.09754735231399536, 0.08988869935274124, 0.06230337917804718, 0.059629205614328384, 0.05961880460381508, 0.05806901678442955, 0.05768990516662598, 0.04538406804203987]
# Time taken: 7.4881 seconds
# --------------------------------------------------------------------------------
#
# Query: What’s the best air purifier to help with allergies?
# Original Category: Home & Kitchen
# Predicted Category: ['Health & Personal Care', 'Home & Kitchen', 'Electronics', 'Beauty', 'Sports & Outdoors', 'Books', 'Tools & Home Improvement', 'Toys & Games', 'Fashion & Apparel', 'Grocery']
# Predicted Scores: [0.4074031114578247, 0.09146034717559814, 0.0845140591263771, 0.07324608415365219, 0.07074581831693649, 0.0683789774775505, 0.05912424251437187, 0.054299838840961456, 0.04656755179166794, 0.04426001384854317]
# Time taken: 6.5323 seconds
# --------------------------------------------------------------------------------
#
# Query: I’m looking for a vacuum cleaner that works well for picking up pet hair.
# Original Category: Home & Kitchen
# Predicted Category: ['Beauty', 'Health & Personal Care', 'Tools & Home Improvement', 'Home & Kitchen', 'Sports & Outdoors', 'Toys & Games', 'Books', 'Electronics', 'Fashion & Apparel', 'Grocery']
# Predicted Scores: [0.18239423632621765, 0.17877256870269775, 0.09982909262180328, 0.09932663291692734, 0.0967053771018982, 0.08807892352342606, 0.08528715372085571, 0.07782185822725296, 0.04708317667245865, 0.044700972735881805]
# Time taken: 6.6104 seconds
# --------------------------------------------------------------------------------
#
# Query: Can you recommend a fridge that’s energy-efficient and has smart features?
# Original Category: Home & Kitchen
# Predicted Category: ['Home & Kitchen', 'Electronics', 'Health & Personal Care', 'Beauty', 'Sports & Outdoors', 'Tools & Home Improvement', 'Grocery', 'Toys & Games', 'Books', 'Fashion & Apparel']
# Predicted Scores: [0.24637392163276672, 0.17664635181427002, 0.10805986821651459, 0.09548443555831909, 0.08465419709682465, 0.07546140253543854, 0.07537294924259186, 0.06511888653039932, 0.038853466510772705, 0.03397458419203758]
# Time taken: 6.8251 seconds
# --------------------------------------------------------------------------------
#
# Query: I want a blue dress for summer that’s comfortable.
# Original Category: Fashion & Apparel
# Predicted Category: ['Fashion & Apparel', 'Beauty', 'Books', 'Sports & Outdoors', 'Home & Kitchen', 'Electronics', 'Health & Personal Care', 'Toys & Games', 'Grocery', 'Tools & Home Improvement']
# Predicted Scores: [0.42400768399238586, 0.1241322010755539, 0.0834968239068985, 0.07431594282388687, 0.07094055414199829, 0.0579674057662487, 0.05592457950115204, 0.04531262814998627, 0.035408951342105865, 0.028493192046880722]
# Time taken: 6.0666 seconds
# --------------------------------------------------------------------------------
#
# Query: Can you help me find waterproof hiking boots for men?
# Original Category: Fashion & Apparel
# Predicted Category: ['Sports & Outdoors', 'Health & Personal Care', 'Beauty', 'Fashion & Apparel', 'Toys & Games', 'Books', 'Home & Kitchen', 'Electronics', 'Tools & Home Improvement', 'Grocery']
# Predicted Scores: [0.647580623626709, 0.09307070821523666, 0.05384201183915138, 0.04170502722263336, 0.03520761802792549, 0.030376533046364784, 0.029090965166687965, 0.024060720577836037, 0.024005474522709846, 0.02106034755706787]
# Time taken: 7.9895 seconds
# --------------------------------------------------------------------------------
#
# Query: I’m looking for a warm jacket for winter that isn’t too bulky.
# Original Category: Fashion & Apparel
# Predicted Category: ['Fashion & Apparel', 'Sports & Outdoors', 'Books', 'Beauty', 'Health & Personal Care', 'Home & Kitchen', 'Electronics', 'Grocery', 'Toys & Games', 'Tools & Home Improvement']
# Predicted Scores: [0.2440132200717926, 0.12649418413639069, 0.10792677849531174, 0.0990976095199585, 0.09720225632190704, 0.08216201514005661, 0.06599662452936172, 0.0643526017665863, 0.06322954595088959, 0.04952527955174446]
# Time taken: 7.0380 seconds
# --------------------------------------------------------------------------------
#
# Query: I need a casual handbag made of leather, but not too expensive.
# Original Category: Fashion & Apparel
# Predicted Category: ['Fashion & Apparel', 'Sports & Outdoors', 'Beauty', 'Home & Kitchen', 'Books', 'Toys & Games', 'Grocery', 'Health & Personal Care', 'Electronics', 'Tools & Home Improvement']
# Predicted Scores: [0.29828116297721863, 0.11609557271003723, 0.11576852947473526, 0.10930263996124268, 0.09730593860149384, 0.08677586913108826, 0.050210192799568176, 0.04742463305592537, 0.046445395797491074, 0.03238997980952263]
# Time taken: 6.4144 seconds
# --------------------------------------------------------------------------------
#
# Query: Can you recommend organic skincare for sensitive skin?
# Original Category: Health & Personal Care
# Predicted Category: ['Beauty', 'Health & Personal Care', 'Home & Kitchen', 'Electronics', 'Grocery', 'Sports & Outdoors', 'Books', 'Toys & Games', 'Tools & Home Improvement', 'Fashion & Apparel']
# Predicted Scores: [0.3522847294807434, 0.26705896854400635, 0.0763649120926857, 0.06367175281047821, 0.05884243920445442, 0.04828513413667679, 0.045297008007764816, 0.039312101900577545, 0.025629226118326187, 0.02325383946299553]
# Time taken: 4.6780 seconds
# --------------------------------------------------------------------------------
#
# Query: I need an electric toothbrush that has a really long battery life.
# Original Category: Health & Personal Care
# Predicted Category: ['Health & Personal Care', 'Electronics', 'Beauty', 'Sports & Outdoors', 'Home & Kitchen', 'Toys & Games', 'Tools & Home Improvement', 'Books', 'Grocery', 'Fashion & Apparel']
# Predicted Scores: [0.33585163950920105, 0.31250444054603577, 0.09612254798412323, 0.06646886467933655, 0.04703132435679436, 0.04258493706583977, 0.031155094504356384, 0.02786259911954403, 0.020929714664816856, 0.019488800317049026]
# Time taken: 5.6906 seconds
# --------------------------------------------------------------------------------
#
# Query: What’s the best hair dryer that works well for frizzy hair?
# Original Category: Health & Personal Care
# Predicted Category: ['Beauty', 'Health & Personal Care', 'Home & Kitchen', 'Electronics', 'Books', 'Grocery', 'Toys & Games', 'Sports & Outdoors', 'Tools & Home Improvement', 'Fashion & Apparel']
# Predicted Scores: [0.21147969365119934, 0.14482834935188293, 0.10555718839168549, 0.10217205435037613, 0.09358125925064087, 0.08240450173616409, 0.08151144534349442, 0.07055766880512238, 0.059877295047044754, 0.0480305440723896]
# Time taken: 7.8542 seconds
# --------------------------------------------------------------------------------
#
# Query: I’m looking for vegan multivitamins that are good for daily use.
# Original Category: Health & Personal Care
# Predicted Category: ['Health & Personal Care', 'Home & Kitchen', 'Beauty', 'Sports & Outdoors', 'Electronics', 'Books', 'Toys & Games', 'Grocery', 'Tools & Home Improvement', 'Fashion & Apparel']
# Predicted Scores: [0.2586257755756378, 0.1506936401128769, 0.12031586468219757, 0.10256724059581757, 0.08695864677429199, 0.08278178423643112, 0.06409977376461029, 0.0475710891187191, 0.04436219483613968, 0.04202406108379364]
# Time taken: 11.4360 seconds
# --------------------------------------------------------------------------------
#
# Query: I need a matte lipstick that lasts all day.
# Original Category: Beauty
# Predicted Category: ['Beauty', 'Health & Personal Care', 'Home & Kitchen', 'Sports & Outdoors', 'Electronics', 'Toys & Games', 'Books', 'Grocery', 'Tools & Home Improvement', 'Fashion & Apparel']
# Predicted Scores: [0.5602102279663086, 0.13151457905769348, 0.07797817140817642, 0.047779381275177, 0.03819641098380089, 0.03605356067419052, 0.03451106697320938, 0.02859884314239025, 0.023105425760149956, 0.022052334621548653]
# Time taken: 4.5703 seconds
# --------------------------------------------------------------------------------
#
# Query: Can you recommend a good anti-aging serum?
# Original Category: Beauty
# Predicted Category: ['Beauty', 'Health & Personal Care', 'Home & Kitchen', 'Electronics', 'Sports & Outdoors', 'Books', 'Toys & Games', 'Grocery', 'Tools & Home Improvement', 'Fashion & Apparel']
# Predicted Scores: [0.3328688144683838, 0.22864654660224915, 0.07953958213329315, 0.07848692685365677, 0.06951072812080383, 0.05687592923641205, 0.051399312913417816, 0.04018963500857353, 0.03369425609707832, 0.02878829836845398]
# Time taken: 5.6628 seconds
# --------------------------------------------------------------------------------
#
# Query: I’m looking for a waterproof eyeliner that won’t smudge easily.
# Original Category: Beauty
# Predicted Category: ['Beauty', 'Health & Personal Care', 'Books', 'Grocery', 'Home & Kitchen', 'Electronics', 'Sports & Outdoors', 'Toys & Games', 'Tools & Home Improvement', 'Fashion & Apparel']
# Predicted Scores: [0.4478971064090729, 0.09998755156993866, 0.07981698960065842, 0.07945762574672699, 0.06493300199508667, 0.05866207554936409, 0.05490904673933983, 0.048239659518003464, 0.03315161168575287, 0.03294536471366882]
# Time taken: 5.8394 seconds
# --------------------------------------------------------------------------------
#
# Query: What’s a good fragrance for summer that’s light and fresh?
# Original Category: Beauty
# Predicted Category: ['Beauty', 'Sports & Outdoors', 'Home & Kitchen', 'Health & Personal Care', 'Grocery', 'Books', 'Electronics', 'Toys & Games', 'Fashion & Apparel', 'Tools & Home Improvement']
# Predicted Scores: [0.19961746037006378, 0.13838407397270203, 0.138184055685997, 0.0943167582154274, 0.08656416833400726, 0.08347790688276291, 0.07535546272993088, 0.07079266756772995, 0.060075290501117706, 0.05323224142193794]
# Time taken: 5.5161 seconds
# --------------------------------------------------------------------------------
#
# Query: I want a lightweight tent for camping with my family.
# Original Category: Sports & Outdoors
# Predicted Category: ['Sports & Outdoors', 'Beauty', 'Electronics', 'Toys & Games', 'Health & Personal Care', 'Books', 'Home & Kitchen', 'Tools & Home Improvement', 'Grocery', 'Fashion & Apparel']
# Predicted Scores: [0.5920923948287964, 0.10735207051038742, 0.05774792283773422, 0.048429571092128754, 0.04674765467643738, 0.0369013287127018, 0.03284037485718727, 0.026957688853144646, 0.026185417547822, 0.024745548143982887]
# Time taken: 5.9169 seconds
# --------------------------------------------------------------------------------
#
# Query: What’s a good mountain bike for a beginner?
# Original Category: Sports & Outdoors
# Predicted Category: ['Sports & Outdoors', 'Beauty', 'Toys & Games', 'Health & Personal Care', 'Books', 'Home & Kitchen', 'Electronics', 'Grocery', 'Tools & Home Improvement', 'Fashion & Apparel']
# Predicted Scores: [0.38771843910217285, 0.1487695276737213, 0.11640136688947678, 0.06125285103917122, 0.058807820081710815, 0.05750376358628273, 0.05387752130627632, 0.05099277198314667, 0.035194139927625656, 0.02948174439370632]
# Time taken: 4.7451 seconds
# --------------------------------------------------------------------------------
#
# Query: Can you recommend a yoga mat that’s comfortable for home workouts?
# Original Category: Sports & Outdoors
# Predicted Category: ['Health & Personal Care', 'Home & Kitchen', 'Beauty', 'Sports & Outdoors', 'Toys & Games', 'Tools & Home Improvement', 'Books', 'Electronics', 'Fashion & Apparel', 'Grocery']
# Predicted Scores: [0.2791576385498047, 0.15781785547733307, 0.1288110762834549, 0.10387606173753738, 0.07849621772766113, 0.06765937060117722, 0.05785302817821503, 0.055580660700798035, 0.03793080151081085, 0.032817281782627106]
# Time taken: 6.4816 seconds
# --------------------------------------------------------------------------------
#
# Query: I need a backpack that’s waterproof and great for hiking.
# Original Category: Sports & Outdoors
# Predicted Category: ['Sports & Outdoors', 'Beauty', 'Health & Personal Care', 'Books', 'Toys & Games', 'Electronics', 'Home & Kitchen', 'Fashion & Apparel', 'Tools & Home Improvement', 'Grocery']
# Predicted Scores: [0.6145873665809631, 0.0883060023188591, 0.05184794217348099, 0.048192162066698074, 0.042119208723306656, 0.03797505050897598, 0.03607097640633583, 0.028791489079594612, 0.02846650220453739, 0.0236432533711195]
# Time taken: 5.1333 seconds
# --------------------------------------------------------------------------------
#
# Query: I’m looking for an educational toy for my 5-year-old.
# Original Category: Toys & Games
# Predicted Category: ['Toys & Games', 'Home & Kitchen', 'Sports & Outdoors', 'Beauty', 'Health & Personal Care', 'Books', 'Fashion & Apparel', 'Electronics', 'Tools & Home Improvement', 'Grocery']
# Predicted Scores: [0.2243853062391281, 0.12084921449422836, 0.09447179734706879, 0.09246266633272171, 0.09176690131425858, 0.08726266026496887, 0.08262272924184799, 0.07726679742336273, 0.07237779349088669, 0.05653413385152817]
# Time taken: 5.5284 seconds
# --------------------------------------------------------------------------------
#
# Query: What’s a good board game for playing with the whole family?
# Original Category: Toys & Games
# Predicted Category: ['Sports & Outdoors', 'Toys & Games', 'Home & Kitchen', 'Tools & Home Improvement', 'Fashion & Apparel', 'Health & Personal Care', 'Beauty', 'Grocery', 'Books', 'Electronics']
# Predicted Scores: [0.1503630429506302, 0.144379660487175, 0.12655772268772125, 0.09572254121303558, 0.09386777877807617, 0.08833897858858109, 0.08779077976942062, 0.07658033072948456, 0.07328348606824875, 0.06311570107936859]
# Time taken: 6.2911 seconds
# --------------------------------------------------------------------------------
#
# Query: My son loves remote control cars. Any recommendations?
# Original Category: Toys & Games
# Predicted Category: ['Electronics', 'Toys & Games', 'Sports & Outdoors', 'Beauty', 'Health & Personal Care', 'Home & Kitchen', 'Tools & Home Improvement', 'Books', 'Grocery', 'Fashion & Apparel']
# Predicted Scores: [0.3245891332626343, 0.2609952390193939, 0.1147269755601883, 0.08191169053316116, 0.052981186658144, 0.04713999480009079, 0.031160926446318626, 0.029831551015377045, 0.02919897809624672, 0.02746441401541233]
# Time taken: 4.6165 seconds
# --------------------------------------------------------------------------------
#
# Query: I need some fun water toys for my kids to play with outside this summer.
# Original Category: Toys & Games
# Predicted Category: ['Sports & Outdoors', 'Toys & Games', 'Beauty', 'Health & Personal Care', 'Home & Kitchen', 'Electronics', 'Grocery', 'Tools & Home Improvement', 'Fashion & Apparel', 'Books']
# Predicted Scores: [0.4135555922985077, 0.27275440096855164, 0.07651223987340927, 0.05506332591176033, 0.054479800164699554, 0.04074058309197426, 0.028227325528860092, 0.02307702973484993, 0.019520478323101997, 0.016069196164608]
# Time taken: 6.6418 seconds
# --------------------------------------------------------------------------------
#
# Query: Can you recommend a good thriller with a female lead?
# Original Category: Books
# Predicted Category: ['Books', 'Beauty', 'Electronics', 'Grocery', 'Home & Kitchen', 'Toys & Games', 'Tools & Home Improvement', 'Health & Personal Care', 'Sports & Outdoors', 'Fashion & Apparel']
# Predicted Scores: [0.2714759409427643, 0.12636952102184296, 0.10264244675636292, 0.0933610051870346, 0.08115612715482712, 0.07755625993013382, 0.07717722654342651, 0.05984197556972504, 0.05574656277894974, 0.0546729639172554]
# Time taken: 4.7099 seconds
# --------------------------------------------------------------------------------
#
# Query: What’s a good book about productivity?
# Original Category: Books
# Predicted Category: ['Books', 'Health & Personal Care', 'Tools & Home Improvement', 'Home & Kitchen', 'Electronics', 'Grocery', 'Beauty', 'Toys & Games', 'Fashion & Apparel', 'Sports & Outdoors']
# Predicted Scores: [0.406982421875, 0.10012481361627579, 0.0982961431145668, 0.08280792087316513, 0.07335378974676132, 0.05935752019286156, 0.05793924257159233, 0.0491759218275547, 0.03635697811841965, 0.0356053002178669]
# Time taken: 4.5917 seconds
# --------------------------------------------------------------------------------
#
# Query: I’m looking for a fantasy series for young adults. Any suggestions?
# Original Category: Books
# Predicted Category: ['Books', 'Electronics', 'Toys & Games', 'Beauty', 'Grocery', 'Sports & Outdoors', 'Home & Kitchen', 'Tools & Home Improvement', 'Health & Personal Care', 'Fashion & Apparel']
# Predicted Scores: [0.43180495500564575, 0.08595774322748184, 0.08338623493909836, 0.07886218279600143, 0.07015854865312576, 0.062405895441770554, 0.05377165973186493, 0.05291782692074776, 0.04577203840017319, 0.03496281057596207]
# Time taken: 6.4293 seconds
# --------------------------------------------------------------------------------
#
# Query: Can you recommend a picture book with animals for kids?
# Original Category: Books
# Predicted Category: ['Books', 'Toys & Games', 'Sports & Outdoors', 'Home & Kitchen', 'Health & Personal Care', 'Beauty', 'Grocery', 'Electronics', 'Tools & Home Improvement', 'Fashion & Apparel']
# Predicted Scores: [0.4859430193901062, 0.08761511743068695, 0.08033572882413864, 0.06573625653982162, 0.060925617814064026, 0.05641738697886467, 0.05087577551603317, 0.047384437173604965, 0.036168601363897324, 0.028597960248589516]
# Time taken: 4.6886 seconds
# --------------------------------------------------------------------------------
#
# Query: I need a cordless drill for some DIY projects around the house.
# Original Category: Tools & Home Improvement
# Predicted Category: ['Tools & Home Improvement', 'Electronics', 'Home & Kitchen', 'Beauty', 'Toys & Games', 'Sports & Outdoors', 'Books', 'Health & Personal Care', 'Fashion & Apparel', 'Grocery']
# Predicted Scores: [0.46590691804885864, 0.31657445430755615, 0.0782797560095787, 0.0437408871948719, 0.027089010924100876, 0.017803195863962173, 0.014084055088460445, 0.013720937073230743, 0.013518709689378738, 0.009282182902097702]
# Time taken: 6.4510 seconds
# --------------------------------------------------------------------------------
#
# Query: What’s a good smart thermostat that will help save on energy?
# Original Category: Tools & Home Improvement
# Predicted Category: ['Home & Kitchen', 'Electronics', 'Beauty', 'Health & Personal Care', 'Sports & Outdoors', 'Books', 'Toys & Games', 'Tools & Home Improvement', 'Fashion & Apparel', 'Grocery']
# Predicted Scores: [0.16684678196907043, 0.16163034737110138, 0.10450857877731323, 0.10389070957899094, 0.09832476079463959, 0.09682533144950867, 0.0790279358625412, 0.07622013986110687, 0.058777958154678345, 0.05394743010401726]
# Time taken: 5.9123 seconds
# --------------------------------------------------------------------------------
#
# Query: I’m looking for power tools for woodwork. Any recommendations?
# Original Category: Tools & Home Improvement
# Predicted Category: ['Tools & Home Improvement', 'Beauty', 'Sports & Outdoors', 'Toys & Games', 'Home & Kitchen', 'Health & Personal Care', 'Books', 'Grocery', 'Electronics', 'Fashion & Apparel']
# Predicted Scores: [0.4524990916252136, 0.13921336829662323, 0.08250782638788223, 0.07811308652162552, 0.056808628141880035, 0.05385889112949371, 0.04239020496606827, 0.036919474601745605, 0.030009716749191284, 0.02767975814640522]
# Time taken: 5.6974 seconds
# --------------------------------------------------------------------------------
#
# Query: I want solar-powered lights for my garden.
# Original Category: Tools & Home Improvement
# Predicted Category: ['Electronics', 'Beauty', 'Sports & Outdoors', 'Tools & Home Improvement', 'Health & Personal Care', 'Toys & Games', 'Home & Kitchen', 'Books', 'Grocery', 'Fashion & Apparel']
# Predicted Scores: [0.21917255222797394, 0.2023933231830597, 0.2004890739917755, 0.10837968438863754, 0.05298677459359169, 0.05252225697040558, 0.05215964466333389, 0.045970041304826736, 0.03859375789761543, 0.027332933619618416]
# Time taken: 5.4105 seconds
# --------------------------------------------------------------------------------
#
# Query: Can you recommend some gluten-free snacks for kids?
# Original Category: Grocery
# Predicted Category: ['Home & Kitchen', 'Health & Personal Care', 'Grocery', 'Beauty', 'Toys & Games', 'Sports & Outdoors', 'Electronics', 'Fashion & Apparel', 'Tools & Home Improvement', 'Books']
# Predicted Scores: [0.1839868724346161, 0.18355660140514374, 0.10811081528663635, 0.09608761966228485, 0.0951283797621727, 0.09286358207464218, 0.09115063399076462, 0.05418818071484566, 0.0541737899184227, 0.04075360670685768]
# Time taken: 4.7081 seconds
# --------------------------------------------------------------------------------
#
# Query: I need keto-friendly ingredients for baking at home.
# Original Category: Grocery
# Predicted Category: ['Home & Kitchen', 'Beauty', 'Electronics', 'Toys & Games', 'Sports & Outdoors', 'Health & Personal Care', 'Books', 'Grocery', 'Fashion & Apparel', 'Tools & Home Improvement']
# Predicted Scores: [0.5617759227752686, 0.11093781888484955, 0.05487474426627159, 0.04925283417105675, 0.04596371203660965, 0.04182785749435425, 0.040586359798908234, 0.037536609917879105, 0.02969428151845932, 0.027549849823117256]
# Time taken: 6.1756 seconds
# --------------------------------------------------------------------------------
#
# Query: What’s the best organic coffee for brewing at home?
# Original Category: Grocery
# Predicted Category: ['Home & Kitchen', 'Beauty', 'Health & Personal Care', 'Sports & Outdoors', 'Books', 'Grocery', 'Electronics', 'Toys & Games', 'Tools & Home Improvement', 'Fashion & Apparel']
# Predicted Scores: [0.3192121684551239, 0.11120069772005081, 0.10315346717834473, 0.09394790977239609, 0.0803285762667656, 0.075649194419384, 0.06893350183963776, 0.059621647000312805, 0.05294227600097656, 0.03501052409410477]
# Time taken: 5.4510 seconds
# --------------------------------------------------------------------------------
#
# Query: What are some good dairy-free milk alternatives?
# Original Category: Grocery
# Predicted Category: ['Home & Kitchen', 'Health & Personal Care', 'Grocery', 'Beauty', 'Sports & Outdoors', 'Toys & Games', 'Books', 'Electronics', 'Tools & Home Improvement', 'Fashion & Apparel']
# Predicted Scores: [0.19385811686515808, 0.15590499341487885, 0.11078998446464539, 0.09649955481290817, 0.0954715684056282, 0.08838111162185669, 0.0829308032989502, 0.07616942375898361, 0.05280580744147301, 0.04718862101435661]
# Time taken: 4.6444 seconds
# --------------------------------------------------------------------------------
#
# Average Time per Query: 6.1836 seconds
# Top-1 Accuracy: 0.6000
# Top-3 Accuracy: 0.8250
# Precision: 0.6421, Recall: 0.6000, F1-Score: 0.5751
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# [0.6, 33, 0.6421428571428571, 0.6, 0.5751082251082252]

# %% [markdown]
# # Zero Shot Classification with Cross-Encoder/Deberta-v3-Base-nli

# %%
from transformers import pipeline

classifier_deberta = pipeline("zero-shot-classification", model='cross-encoder/nli-deberta-v3-base')
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/convert_slow_tokenizer.py:551: UserWarning: The sentencepiece tokenizer that you are converting to a fast tokenizer uses the byte fallback option which is not implemented in the fast tokenizers. In practice this means that the fast version of the tokenizer can produce unknown tokens whereas the sentencepiece version would have converted these unknown tokens into a sequence of byte tokens matching the original piece of text.
#   warnings.warn(

# %%
# Main function to run classification and evaluation
def main(queries_with_categories, candidate_labels, classifier):
    # Run the classification
    results = run_classification(queries_with_categories, candidate_labels, classifier)

    # Evaluate the predictions
    evaluation_metrics = evaluate_predictions(results)
    return evaluation_metrics

# Call the main function
main(queries_with_categories, candidate_labels, classifier_deberta)
# Out:
# Query: I need a phone with a really good camera for under $500.
# Original Category: Electronics
# Predicted Category: ['Electronics', 'Sports & Outdoors', 'Fashion & Apparel', 'Beauty', 'Home & Kitchen', 'Grocery', 'Health & Personal Care', 'Books', 'Toys & Games', 'Tools & Home Improvement']
# Predicted Scores: [0.9707419276237488, 0.008652317337691784, 0.004545948468148708, 0.004464976955205202, 0.0036659655161201954, 0.00303573883138597, 0.0018449216149747372, 0.0011541432468220592, 0.0009503174223937094, 0.0009438643464818597]
# Time taken: 3.6638 seconds
# --------------------------------------------------------------------------------
#
# Query: What’s the best wireless headset for working from home?
# Original Category: Electronics
# Predicted Category: ['Electronics', 'Home & Kitchen', 'Sports & Outdoors', 'Tools & Home Improvement', 'Grocery', 'Health & Personal Care', 'Fashion & Apparel', 'Books', 'Beauty', 'Toys & Games']
# Predicted Scores: [0.9521678686141968, 0.009584474377334118, 0.006928279530256987, 0.0064592971466481686, 0.006070664152503014, 0.006041298620402813, 0.004553651437163353, 0.003890514373779297, 0.0021805991418659687, 0.0021232995204627514]
# Time taken: 3.6530 seconds
# --------------------------------------------------------------------------------
#
# Query: Can you suggest a smartwatch that works with iPhones?
# Original Category: Electronics
# Predicted Category: ['Electronics', 'Fashion & Apparel', 'Health & Personal Care', 'Sports & Outdoors', 'Home & Kitchen', 'Grocery', 'Books', 'Toys & Games', 'Tools & Home Improvement', 'Beauty']
# Predicted Scores: [0.9466752409934998, 0.020637288689613342, 0.006414010189473629, 0.005507899913936853, 0.005020195618271828, 0.004528507590293884, 0.003418934065848589, 0.003347742138430476, 0.0023810970596969128, 0.0020690709352493286]
# Time taken: 4.7976 seconds
# --------------------------------------------------------------------------------
#
# Query: I’m looking for a TV that has both 4K and Dolby Vision support.
# Original Category: Electronics
# Predicted Category: ['Electronics', 'Fashion & Apparel', 'Toys & Games', 'Home & Kitchen', 'Grocery', 'Beauty', 'Books', 'Sports & Outdoors', 'Health & Personal Care', 'Tools & Home Improvement']
# Predicted Scores: [0.9870671033859253, 0.0024637659080326557, 0.001983570633456111, 0.0017504150746390224, 0.0015938997967168689, 0.0015039140125736594, 0.0013022917555645108, 0.0009712923783808947, 0.0007849298417568207, 0.0005788380512967706]
# Time taken: 3.7190 seconds
# --------------------------------------------------------------------------------
#
# Query: I want a set of non-stick pans that last long and are easy to clean.
# Original Category: Home & Kitchen
# Predicted Category: ['Tools & Home Improvement', 'Home & Kitchen', 'Health & Personal Care', 'Grocery', 'Sports & Outdoors', 'Beauty', 'Books', 'Fashion & Apparel', 'Electronics', 'Toys & Games']
# Predicted Scores: [0.8354206681251526, 0.057334430515766144, 0.024574408307671547, 0.024380577728152275, 0.023884639143943787, 0.010699625127017498, 0.008009523153305054, 0.006515360902994871, 0.004806790966540575, 0.004373989999294281]
# Time taken: 3.7234 seconds
# --------------------------------------------------------------------------------
#
# Query: What’s the best air purifier to help with allergies?
# Original Category: Home & Kitchen
# Predicted Category: ['Health & Personal Care', 'Electronics', 'Home & Kitchen', 'Fashion & Apparel', 'Grocery', 'Toys & Games', 'Sports & Outdoors', 'Tools & Home Improvement', 'Books', 'Beauty']
# Predicted Scores: [0.3763580322265625, 0.20735661685466766, 0.0777534693479538, 0.05693685635924339, 0.053899507969617844, 0.05169830098748207, 0.05025618523359299, 0.04895295947790146, 0.044714558869600296, 0.03207352012395859]
# Time taken: 4.9786 seconds
# --------------------------------------------------------------------------------
#
# Query: I’m looking for a vacuum cleaner that works well for picking up pet hair.
# Original Category: Home & Kitchen
# Predicted Category: ['Electronics', 'Sports & Outdoors', 'Tools & Home Improvement', 'Health & Personal Care', 'Grocery', 'Books', 'Fashion & Apparel', 'Toys & Games', 'Beauty', 'Home & Kitchen']
# Predicted Scores: [0.9638778567314148, 0.012344681657850742, 0.008951031602919102, 0.00445704348385334, 0.0031777890399098396, 0.0022940603084862232, 0.001662899274379015, 0.001523679355159402, 0.0012078155996277928, 0.0005031491164118052]
# Time taken: 3.6855 seconds
# --------------------------------------------------------------------------------
#
# Query: Can you recommend a fridge that’s energy-efficient and has smart features?
# Original Category: Home & Kitchen
# Predicted Category: ['Electronics', 'Home & Kitchen', 'Tools & Home Improvement', 'Health & Personal Care', 'Fashion & Apparel', 'Sports & Outdoors', 'Grocery', 'Books', 'Toys & Games', 'Beauty']
# Predicted Scores: [0.6826515793800354, 0.08783826231956482, 0.064336396753788, 0.02927788905799389, 0.028345275670289993, 0.024477656930685043, 0.023493856191635132, 0.023085927590727806, 0.020023588091135025, 0.016469476744532585]
# Time taken: 3.6603 seconds
# --------------------------------------------------------------------------------
#
# Query: I want a blue dress for summer that’s comfortable.
# Original Category: Fashion & Apparel
# Predicted Category: ['Fashion & Apparel', 'Beauty', 'Health & Personal Care', 'Sports & Outdoors', 'Books', 'Grocery', 'Home & Kitchen', 'Electronics', 'Toys & Games', 'Tools & Home Improvement']
# Predicted Scores: [0.9276266694068909, 0.042493000626564026, 0.008866204880177975, 0.008303189650177956, 0.0033623836934566498, 0.0032316280994564295, 0.0029590146150439978, 0.0012407508911564946, 0.0010688701877370477, 0.0008483343990519643]
# Time taken: 4.1201 seconds
# --------------------------------------------------------------------------------
#
# Query: Can you help me find waterproof hiking boots for men?
# Original Category: Fashion & Apparel
# Predicted Category: ['Sports & Outdoors', 'Health & Personal Care', 'Beauty', 'Fashion & Apparel', 'Grocery', 'Tools & Home Improvement', 'Electronics', 'Home & Kitchen', 'Books', 'Toys & Games']
# Predicted Scores: [0.9523531198501587, 0.020775262266397476, 0.007039405405521393, 0.006048649549484253, 0.003461139975115657, 0.0028280136175453663, 0.0021261319052428007, 0.0020096153020858765, 0.0019367658533155918, 0.0014218289870768785]
# Time taken: 5.7812 seconds
# --------------------------------------------------------------------------------
#
# Query: I’m looking for a warm jacket for winter that isn’t too bulky.
# Original Category: Fashion & Apparel
# Predicted Category: ['Fashion & Apparel', 'Health & Personal Care', 'Sports & Outdoors', 'Electronics', 'Grocery', 'Books', 'Tools & Home Improvement', 'Beauty', 'Toys & Games', 'Home & Kitchen']
# Predicted Scores: [0.43965521454811096, 0.2357507050037384, 0.18213903903961182, 0.02540874481201172, 0.024728329852223396, 0.021364456042647362, 0.021129727363586426, 0.019648920744657516, 0.015836365520954132, 0.014338343404233456]
# Time taken: 3.9642 seconds
# --------------------------------------------------------------------------------
#
# Query: I need a casual handbag made of leather, but not too expensive.
# Original Category: Fashion & Apparel
# Predicted Category: ['Fashion & Apparel', 'Sports & Outdoors', 'Beauty', 'Grocery', 'Health & Personal Care', 'Books', 'Home & Kitchen', 'Electronics', 'Toys & Games', 'Tools & Home Improvement']
# Predicted Scores: [0.9460864067077637, 0.01604882813990116, 0.011945433914661407, 0.009620770812034607, 0.007267349399626255, 0.0025201495736837387, 0.002455642446875572, 0.0019148358842357993, 0.0012136958539485931, 0.0009268212597817183]
# Time taken: 4.2509 seconds
# --------------------------------------------------------------------------------
#
# Query: Can you recommend organic skincare for sensitive skin?
# Original Category: Health & Personal Care
# Predicted Category: ['Health & Personal Care', 'Sports & Outdoors', 'Beauty', 'Home & Kitchen', 'Grocery', 'Fashion & Apparel', 'Toys & Games', 'Tools & Home Improvement', 'Books', 'Electronics']
# Predicted Scores: [0.37677693367004395, 0.24605359137058258, 0.1040133461356163, 0.09544616937637329, 0.058391936123371124, 0.035648196935653687, 0.028791241347789764, 0.022120676934719086, 0.017704244703054428, 0.01505374163389206]
# Time taken: 4.1858 seconds
# --------------------------------------------------------------------------------
#
# Query: I need an electric toothbrush that has a really long battery life.
# Original Category: Health & Personal Care
# Predicted Category: ['Electronics', 'Health & Personal Care', 'Home & Kitchen', 'Tools & Home Improvement', 'Sports & Outdoors', 'Grocery', 'Beauty', 'Fashion & Apparel', 'Books', 'Toys & Games']
# Predicted Scores: [0.7217543125152588, 0.2606220841407776, 0.0048084682784974575, 0.004257852211594582, 0.0035705326590687037, 0.0018246996914967895, 0.0016314982203766704, 0.0006458841380663216, 0.0005136469262652099, 0.0003711776516865939]
# Time taken: 3.5427 seconds
# --------------------------------------------------------------------------------
#
# Query: What’s the best hair dryer that works well for frizzy hair?
# Original Category: Health & Personal Care
# Predicted Category: ['Electronics', 'Health & Personal Care', 'Tools & Home Improvement', 'Sports & Outdoors', 'Fashion & Apparel', 'Home & Kitchen', 'Beauty', 'Toys & Games', 'Grocery', 'Books']
# Predicted Scores: [0.2988378703594208, 0.15159054100513458, 0.14355087280273438, 0.10699944198131561, 0.06202882155776024, 0.05991024523973465, 0.052075620740652084, 0.04691252112388611, 0.04416224732995033, 0.03393183648586273]
# Time taken: 3.5732 seconds
# --------------------------------------------------------------------------------
#
# Query: I’m looking for vegan multivitamins that are good for daily use.
# Original Category: Health & Personal Care
# Predicted Category: ['Health & Personal Care', 'Grocery', 'Home & Kitchen', 'Electronics', 'Fashion & Apparel', 'Books', 'Sports & Outdoors', 'Toys & Games', 'Tools & Home Improvement', 'Beauty']
# Predicted Scores: [0.4759497344493866, 0.09917808324098587, 0.09509676694869995, 0.06581877917051315, 0.055114734917879105, 0.04769229143857956, 0.04389208182692528, 0.04270021617412567, 0.04169205576181412, 0.03286529704928398]
# Time taken: 5.0812 seconds
# --------------------------------------------------------------------------------
#
# Query: I need a matte lipstick that lasts all day.
# Original Category: Beauty
# Predicted Category: ['Fashion & Apparel', 'Beauty', 'Books', 'Home & Kitchen', 'Grocery', 'Health & Personal Care', 'Sports & Outdoors', 'Electronics', 'Toys & Games', 'Tools & Home Improvement']
# Predicted Scores: [0.5822195410728455, 0.1026449128985405, 0.08587078005075455, 0.0849635973572731, 0.04831530898809433, 0.03729864954948425, 0.025892019271850586, 0.01424746960401535, 0.013462556526064873, 0.00508517399430275]
# Time taken: 3.5061 seconds
# --------------------------------------------------------------------------------
#
# Query: Can you recommend a good anti-aging serum?
# Original Category: Beauty
# Predicted Category: ['Health & Personal Care', 'Sports & Outdoors', 'Home & Kitchen', 'Fashion & Apparel', 'Beauty', 'Toys & Games', 'Electronics', 'Tools & Home Improvement', 'Grocery', 'Books']
# Predicted Scores: [0.45222198963165283, 0.12543654441833496, 0.11639408767223358, 0.05852248892188072, 0.058220334351062775, 0.04453938826918602, 0.043645765632390976, 0.03974844142794609, 0.03574050962924957, 0.025530466809868813]
# Time taken: 3.4614 seconds
# --------------------------------------------------------------------------------
#
# Query: I’m looking for a waterproof eyeliner that won’t smudge easily.
# Original Category: Beauty
# Predicted Category: ['Fashion & Apparel', 'Health & Personal Care', 'Electronics', 'Sports & Outdoors', 'Books', 'Grocery', 'Beauty', 'Tools & Home Improvement', 'Home & Kitchen', 'Toys & Games']
# Predicted Scores: [0.21085147559642792, 0.18919996917247772, 0.11203945428133011, 0.10233688354492188, 0.09267197549343109, 0.07326996326446533, 0.06474309414625168, 0.06458563357591629, 0.04992714524269104, 0.04037440940737724]
# Time taken: 4.4031 seconds
# --------------------------------------------------------------------------------
#
# Query: What’s a good fragrance for summer that’s light and fresh?
# Original Category: Beauty
# Predicted Category: ['Fashion & Apparel', 'Beauty', 'Home & Kitchen', 'Sports & Outdoors', 'Grocery', 'Health & Personal Care', 'Electronics', 'Books', 'Tools & Home Improvement', 'Toys & Games']
# Predicted Scores: [0.19762881100177765, 0.12553556263446808, 0.1165943518280983, 0.11153580248355865, 0.09226915240287781, 0.0858076885342598, 0.07529082894325256, 0.07501190155744553, 0.0653892308473587, 0.054936736822128296]
# Time taken: 4.1144 seconds
# --------------------------------------------------------------------------------
#
# Query: I want a lightweight tent for camping with my family.
# Original Category: Sports & Outdoors
# Predicted Category: ['Sports & Outdoors', 'Health & Personal Care', 'Grocery', 'Fashion & Apparel', 'Beauty', 'Books', 'Electronics', 'Tools & Home Improvement', 'Toys & Games', 'Home & Kitchen']
# Predicted Scores: [0.911244809627533, 0.06377231329679489, 0.005008227191865444, 0.0047651901841163635, 0.003202183870598674, 0.003083864226937294, 0.0029970314353704453, 0.0027979426085948944, 0.0020595311652868986, 0.0010688821785151958]
# Time taken: 3.4922 seconds
# --------------------------------------------------------------------------------
#
# Query: What’s a good mountain bike for a beginner?
# Original Category: Sports & Outdoors
# Predicted Category: ['Sports & Outdoors', 'Fashion & Apparel', 'Books', 'Grocery', 'Health & Personal Care', 'Toys & Games', 'Electronics', 'Home & Kitchen', 'Tools & Home Improvement', 'Beauty']
# Predicted Scores: [0.9910243153572083, 0.0014223700854927301, 0.001230569207109511, 0.001193458796478808, 0.0010667971801012754, 0.0010392277035862207, 0.0009735746425576508, 0.0008242580806836486, 0.0006949188536964357, 0.0005304551450535655]
# Time taken: 3.4979 seconds
# --------------------------------------------------------------------------------
#
# Query: Can you recommend a yoga mat that’s comfortable for home workouts?
# Original Category: Sports & Outdoors
# Predicted Category: ['Health & Personal Care', 'Sports & Outdoors', 'Fashion & Apparel', 'Grocery', 'Electronics', 'Home & Kitchen', 'Books', 'Beauty', 'Tools & Home Improvement', 'Toys & Games']
# Predicted Scores: [0.3620307147502899, 0.20371441543102264, 0.14768698811531067, 0.05751814693212509, 0.04946991428732872, 0.04398814216256142, 0.041111432015895844, 0.0361051969230175, 0.030974801629781723, 0.02740020491182804]
# Time taken: 5.0381 seconds
# --------------------------------------------------------------------------------
#
# Query: I need a backpack that’s waterproof and great for hiking.
# Original Category: Sports & Outdoors
# Predicted Category: ['Sports & Outdoors', 'Grocery', 'Health & Personal Care', 'Electronics', 'Fashion & Apparel', 'Books', 'Home & Kitchen', 'Beauty', 'Tools & Home Improvement', 'Toys & Games']
# Predicted Scores: [0.9823485016822815, 0.0034436150453984737, 0.0026582616847008467, 0.002425669925287366, 0.002138413256034255, 0.0017829698044806719, 0.0015124771744012833, 0.0013445538934320211, 0.00121667783241719, 0.0011287883389741182]
# Time taken: 3.5413 seconds
# --------------------------------------------------------------------------------
#
# Query: I’m looking for an educational toy for my 5-year-old.
# Original Category: Toys & Games
# Predicted Category: ['Toys & Games', 'Electronics', 'Health & Personal Care', 'Fashion & Apparel', 'Sports & Outdoors', 'Books', 'Tools & Home Improvement', 'Home & Kitchen', 'Grocery', 'Beauty']
# Predicted Scores: [0.37808293104171753, 0.20896080136299133, 0.07629632949829102, 0.06953173130750656, 0.06732458621263504, 0.060912955552339554, 0.04562512785196304, 0.03373108059167862, 0.03137752413749695, 0.028156911954283714]
# Time taken: 3.6758 seconds
# --------------------------------------------------------------------------------
#
# Query: What’s a good board game for playing with the whole family?
# Original Category: Toys & Games
# Predicted Category: ['Toys & Games', 'Electronics', 'Grocery', 'Home & Kitchen', 'Beauty', 'Fashion & Apparel', 'Health & Personal Care', 'Sports & Outdoors', 'Books', 'Tools & Home Improvement']
# Predicted Scores: [0.37872615456581116, 0.10423454642295837, 0.0832166001200676, 0.08113933354616165, 0.07013671100139618, 0.06778515130281448, 0.0648992657661438, 0.06348702311515808, 0.04421132430434227, 0.042163778096437454]
# Time taken: 4.6680 seconds
# --------------------------------------------------------------------------------
#
# Query: My son loves remote control cars. Any recommendations?
# Original Category: Toys & Games
# Predicted Category: ['Electronics', 'Toys & Games', 'Sports & Outdoors', 'Beauty', 'Health & Personal Care', 'Fashion & Apparel', 'Grocery', 'Home & Kitchen', 'Books', 'Tools & Home Improvement']
# Predicted Scores: [0.7679328322410583, 0.1562952995300293, 0.04423496127128601, 0.006929886527359486, 0.005206910893321037, 0.004930607974529266, 0.004285644739866257, 0.0037632700987160206, 0.00331895356066525, 0.003101667622104287]
# Time taken: 3.5553 seconds
# --------------------------------------------------------------------------------
#
# Query: I need some fun water toys for my kids to play with outside this summer.
# Original Category: Toys & Games
# Predicted Category: ['Sports & Outdoors', 'Toys & Games', 'Grocery', 'Health & Personal Care', 'Fashion & Apparel', 'Home & Kitchen', 'Electronics', 'Tools & Home Improvement', 'Books', 'Beauty']
# Predicted Scores: [0.5053151249885559, 0.42535293102264404, 0.01521827932447195, 0.013673481531441212, 0.00932555366307497, 0.007996773347258568, 0.007147627882659435, 0.006393637042492628, 0.005182571709156036, 0.004394087474793196]
# Time taken: 3.6456 seconds
# --------------------------------------------------------------------------------
#
# Query: Can you recommend a good thriller with a female lead?
# Original Category: Books
# Predicted Category: ['Beauty', 'Fashion & Apparel', 'Books', 'Sports & Outdoors', 'Electronics', 'Toys & Games', 'Grocery', 'Home & Kitchen', 'Health & Personal Care', 'Tools & Home Improvement']
# Predicted Scores: [0.17958521842956543, 0.13137462735176086, 0.12822405993938446, 0.10470369458198547, 0.10310710221529007, 0.09052266925573349, 0.07991675287485123, 0.06346584111452103, 0.060203667730093, 0.058896422386169434]
# Time taken: 3.8136 seconds
# --------------------------------------------------------------------------------
#
# Query: What’s a good book about productivity?
# Original Category: Books
# Predicted Category: ['Books', 'Grocery', 'Beauty', 'Home & Kitchen', 'Toys & Games', 'Sports & Outdoors', 'Fashion & Apparel', 'Tools & Home Improvement', 'Electronics', 'Health & Personal Care']
# Predicted Scores: [0.508016049861908, 0.09313797950744629, 0.07305829972028732, 0.0602605864405632, 0.0574227049946785, 0.04782290384173393, 0.04749855399131775, 0.04536322504281998, 0.04372047260403633, 0.02369917370378971]
# Time taken: 4.5625 seconds
# --------------------------------------------------------------------------------
#
# Query: I’m looking for a fantasy series for young adults. Any suggestions?
# Original Category: Books
# Predicted Category: ['Books', 'Toys & Games', 'Sports & Outdoors', 'Electronics', 'Grocery', 'Health & Personal Care', 'Fashion & Apparel', 'Home & Kitchen', 'Beauty', 'Tools & Home Improvement']
# Predicted Scores: [0.3124050199985504, 0.1173928752541542, 0.09637121856212616, 0.09178053587675095, 0.08400648832321167, 0.08181069046258926, 0.07590480148792267, 0.06390657275915146, 0.04854681342840195, 0.027875008061528206]
# Time taken: 3.6697 seconds
# --------------------------------------------------------------------------------
#
# Query: Can you recommend a picture book with animals for kids?
# Original Category: Books
# Predicted Category: ['Books', 'Toys & Games', 'Grocery', 'Fashion & Apparel', 'Sports & Outdoors', 'Health & Personal Care', 'Electronics', 'Tools & Home Improvement', 'Home & Kitchen', 'Beauty']
# Predicted Scores: [0.4074542820453644, 0.10407597571611404, 0.09328146278858185, 0.07549449801445007, 0.07009400427341461, 0.06664704531431198, 0.06283143907785416, 0.047963060438632965, 0.04253804683685303, 0.029620157554745674]
# Time taken: 3.5043 seconds
# --------------------------------------------------------------------------------
#
# Query: I need a cordless drill for some DIY projects around the house.
# Original Category: Tools & Home Improvement
# Predicted Category: ['Tools & Home Improvement', 'Electronics', 'Home & Kitchen', 'Health & Personal Care', 'Sports & Outdoors', 'Grocery', 'Fashion & Apparel', 'Books', 'Beauty', 'Toys & Games']
# Predicted Scores: [0.6922492384910583, 0.28544968366622925, 0.008063873276114464, 0.003245569532737136, 0.002251868601888418, 0.0022103330120444298, 0.0020093275234103203, 0.0017313179560005665, 0.0014764072839170694, 0.0013123864773660898]
# Time taken: 5.0027 seconds
# --------------------------------------------------------------------------------
#
# Query: What’s a good smart thermostat that will help save on energy?
# Original Category: Tools & Home Improvement
# Predicted Category: ['Electronics', 'Health & Personal Care', 'Home & Kitchen', 'Grocery', 'Toys & Games', 'Tools & Home Improvement', 'Books', 'Fashion & Apparel', 'Sports & Outdoors', 'Beauty']
# Predicted Scores: [0.62424236536026, 0.08391403406858444, 0.05944843217730522, 0.04596329852938652, 0.04298517107963562, 0.0396060086786747, 0.03618139028549194, 0.03486274555325508, 0.022664107382297516, 0.01013243943452835]
# Time taken: 3.5771 seconds
# --------------------------------------------------------------------------------
#
# Query: I’m looking for power tools for woodwork. Any recommendations?
# Original Category: Tools & Home Improvement
# Predicted Category: ['Tools & Home Improvement', 'Home & Kitchen', 'Beauty', 'Sports & Outdoors', 'Grocery', 'Electronics', 'Toys & Games', 'Fashion & Apparel', 'Health & Personal Care', 'Books']
# Predicted Scores: [0.9017884135246277, 0.020742053166031837, 0.016832230612635612, 0.013004627078771591, 0.011728816665709019, 0.009417273104190826, 0.007519498933106661, 0.006565457209944725, 0.006213557440787554, 0.0061880843713879585]
# Time taken: 3.5788 seconds
# --------------------------------------------------------------------------------
#
# Query: I want solar-powered lights for my garden.
# Original Category: Tools & Home Improvement
# Predicted Category: ['Electronics', 'Beauty', 'Sports & Outdoors', 'Tools & Home Improvement', 'Health & Personal Care', 'Grocery', 'Home & Kitchen', 'Fashion & Apparel', 'Books', 'Toys & Games']
# Predicted Scores: [0.7977699041366577, 0.06473910063505173, 0.0644056648015976, 0.028228040784597397, 0.012901579029858112, 0.010902377776801586, 0.006896460894495249, 0.005541927646845579, 0.005213666241616011, 0.003401206573471427]
# Time taken: 3.8329 seconds
# --------------------------------------------------------------------------------
#
# Query: Can you recommend some gluten-free snacks for kids?
# Original Category: Grocery
# Predicted Category: ['Sports & Outdoors', 'Grocery', 'Health & Personal Care', 'Home & Kitchen', 'Beauty', 'Tools & Home Improvement', 'Fashion & Apparel', 'Electronics', 'Toys & Games', 'Books']
# Predicted Scores: [0.341482549905777, 0.20664258301258087, 0.13295382261276245, 0.112645722925663, 0.044604282826185226, 0.041503969579935074, 0.03660673275589943, 0.03326727822422981, 0.030865199863910675, 0.01942790485918522]
# Time taken: 4.5569 seconds
# --------------------------------------------------------------------------------
#
# Query: I need keto-friendly ingredients for baking at home.
# Original Category: Grocery
# Predicted Category: ['Home & Kitchen', 'Health & Personal Care', 'Grocery', 'Sports & Outdoors', 'Beauty', 'Tools & Home Improvement', 'Electronics', 'Fashion & Apparel', 'Toys & Games', 'Books']
# Predicted Scores: [0.4987405836582184, 0.13027408719062805, 0.10784558951854706, 0.055259741842746735, 0.05310411378741264, 0.040866829454898834, 0.03359511122107506, 0.030223941430449486, 0.02530675008893013, 0.024783309549093246]
# Time taken: 3.5344 seconds
# --------------------------------------------------------------------------------
#
# Query: What’s the best organic coffee for brewing at home?
# Original Category: Grocery
# Predicted Category: ['Home & Kitchen', 'Health & Personal Care', 'Sports & Outdoors', 'Toys & Games', 'Electronics', 'Fashion & Apparel', 'Tools & Home Improvement', 'Grocery', 'Books', 'Beauty']
# Predicted Scores: [0.19909478724002838, 0.17456084489822388, 0.14524610340595245, 0.10868051648139954, 0.09426634758710861, 0.08296233415603638, 0.0655747726559639, 0.04896152764558792, 0.046967048197984695, 0.033685676753520966]
# Time taken: 3.5464 seconds
# --------------------------------------------------------------------------------
#
# Query: What are some good dairy-free milk alternatives?
# Original Category: Grocery
# Predicted Category: ['Health & Personal Care', 'Home & Kitchen', 'Sports & Outdoors', 'Grocery', 'Beauty', 'Electronics', 'Toys & Games', 'Books', 'Fashion & Apparel', 'Tools & Home Improvement']
# Predicted Scores: [0.2540040910243988, 0.2164904922246933, 0.10669081658124924, 0.08625779300928116, 0.06788741052150726, 0.06506731361150742, 0.05744122713804245, 0.05445176362991333, 0.047605227679014206, 0.04410389065742493]
# Time taken: 4.8353 seconds
# --------------------------------------------------------------------------------
#
# Average Time per Query: 4.0249 seconds
# Top-1 Accuracy: 0.4750
# Top-3 Accuracy: 0.8000
# Precision: 0.4364, Recall: 0.4750, F1-Score: 0.4229
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# [0.475, 32, 0.43636363636363634, 0.475, 0.4228571428571429]

# %% [markdown]
# # Zero Shot Classification with typeform/distilbert-base-uncased-mnli

# %%
from transformers import pipeline

classifier_distilbert = pipeline("zero-shot-classification", model='typeform/distilbert-base-uncased-mnli')
# Out:
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.

# %%
# Main function to run classification and evaluation
def main(queries_with_categories, candidate_labels, classifier):
    # Run the classification
    results = run_classification(queries_with_categories, candidate_labels, classifier)

    # Evaluate the predictions
    evaluation_metrics = evaluate_predictions(results)
    return evaluation_metrics

# Call the main function
main(queries_with_categories, candidate_labels, classifier_distilbert)
# Out:
# Query: I need a phone with a really good camera for under $500.
# Original Category: Electronics
# Predicted Category: ['Electronics', 'Beauty', 'Tools & Home Improvement', 'Health & Personal Care', 'Home & Kitchen', 'Sports & Outdoors', 'Fashion & Apparel', 'Toys & Games', 'Grocery', 'Books']
# Predicted Scores: [0.6001147031784058, 0.10776521265506744, 0.05732416734099388, 0.04956219717860222, 0.04530344903469086, 0.04472143203020096, 0.03775296360254288, 0.026158669963479042, 0.01603618636727333, 0.015260972082614899]
# Time taken: 0.9095 seconds
# --------------------------------------------------------------------------------
#
# Query: What’s the best wireless headset for working from home?
# Original Category: Electronics
# Predicted Category: ['Electronics', 'Beauty', 'Tools & Home Improvement', 'Health & Personal Care', 'Sports & Outdoors', 'Fashion & Apparel', 'Books', 'Grocery', 'Home & Kitchen', 'Toys & Games']
# Predicted Scores: [0.9862163662910461, 0.00411610770970583, 0.0035344120115041733, 0.0019793580286204815, 0.0010415647411718965, 0.0008103519212454557, 0.0007833279087208211, 0.0006168261752463877, 0.0005065780133008957, 0.00039512073271907866]
# Time taken: 0.9004 seconds
# --------------------------------------------------------------------------------
#
# Query: Can you suggest a smartwatch that works with iPhones?
# Original Category: Electronics
# Predicted Category: ['Electronics', 'Beauty', 'Health & Personal Care', 'Tools & Home Improvement', 'Sports & Outdoors', 'Fashion & Apparel', 'Books', 'Toys & Games', 'Grocery', 'Home & Kitchen']
# Predicted Scores: [0.8071898818016052, 0.03881334140896797, 0.036643341183662415, 0.03199587017297745, 0.01733279600739479, 0.017192503437399864, 0.014766347594559193, 0.014058875851333141, 0.011128018610179424, 0.010879052802920341]
# Time taken: 0.9578 seconds
# --------------------------------------------------------------------------------
#
# Query: I’m looking for a TV that has both 4K and Dolby Vision support.
# Original Category: Electronics
# Predicted Category: ['Electronics', 'Health & Personal Care', 'Tools & Home Improvement', 'Beauty', 'Sports & Outdoors', 'Home & Kitchen', 'Toys & Games', 'Grocery', 'Fashion & Apparel', 'Books']
# Predicted Scores: [0.32349133491516113, 0.15446670353412628, 0.1098719909787178, 0.10538598895072937, 0.08870403468608856, 0.062182050198316574, 0.05345478281378746, 0.04217933118343353, 0.03171628713607788, 0.028547445312142372]
# Time taken: 0.9400 seconds
# --------------------------------------------------------------------------------
#
# Query: I want a set of non-stick pans that last long and are easy to clean.
# Original Category: Home & Kitchen
# Predicted Category: ['Home & Kitchen', 'Beauty', 'Health & Personal Care', 'Electronics', 'Tools & Home Improvement', 'Fashion & Apparel', 'Sports & Outdoors', 'Toys & Games', 'Grocery', 'Books']
# Predicted Scores: [0.17714020609855652, 0.17584362626075745, 0.13801489770412445, 0.12638306617736816, 0.09429612010717392, 0.08917174488306046, 0.08559156954288483, 0.03992399945855141, 0.036917269229888916, 0.0367174856364727]
# Time taken: 0.6936 seconds
# --------------------------------------------------------------------------------
#
# Query: What’s the best air purifier to help with allergies?
# Original Category: Home & Kitchen
# Predicted Category: ['Health & Personal Care', 'Tools & Home Improvement', 'Electronics', 'Beauty', 'Fashion & Apparel', 'Sports & Outdoors', 'Home & Kitchen', 'Books', 'Grocery', 'Toys & Games']
# Predicted Scores: [0.6260198354721069, 0.13286122679710388, 0.07357432693243027, 0.07318314164876938, 0.02058786153793335, 0.01854822412133217, 0.017333056777715683, 0.015038847923278809, 0.012285063043236732, 0.010568425990641117]
# Time taken: 0.6553 seconds
# --------------------------------------------------------------------------------
#
# Query: I’m looking for a vacuum cleaner that works well for picking up pet hair.
# Original Category: Home & Kitchen
# Predicted Category: ['Electronics', 'Tools & Home Improvement', 'Health & Personal Care', 'Beauty', 'Home & Kitchen', 'Fashion & Apparel', 'Toys & Games', 'Sports & Outdoors', 'Grocery', 'Books']
# Predicted Scores: [0.3866560757160187, 0.15194690227508545, 0.10452979803085327, 0.08429048955440521, 0.08061634004116058, 0.07177598774433136, 0.040383029729127884, 0.031257208436727524, 0.02636720985174179, 0.022176964208483696]
# Time taken: 0.6724 seconds
# --------------------------------------------------------------------------------
#
# Query: Can you recommend a fridge that’s energy-efficient and has smart features?
# Original Category: Home & Kitchen
# Predicted Category: ['Home & Kitchen', 'Health & Personal Care', 'Beauty', 'Tools & Home Improvement', 'Electronics', 'Grocery', 'Books', 'Fashion & Apparel', 'Sports & Outdoors', 'Toys & Games']
# Predicted Scores: [0.26920953392982483, 0.21702799201011658, 0.1773119568824768, 0.13781042397022247, 0.06417997181415558, 0.03344215825200081, 0.03125954791903496, 0.030317552387714386, 0.021834196522831917, 0.01760670356452465]
# Time taken: 0.6714 seconds
# --------------------------------------------------------------------------------
#
# Query: I want a blue dress for summer that’s comfortable.
# Original Category: Fashion & Apparel
# Predicted Category: ['Fashion & Apparel', 'Beauty', 'Health & Personal Care', 'Sports & Outdoors', 'Tools & Home Improvement', 'Home & Kitchen', 'Grocery', 'Electronics', 'Books', 'Toys & Games']
# Predicted Scores: [0.6962555646896362, 0.12363644689321518, 0.0638481006026268, 0.03310512378811836, 0.025431327521800995, 0.021054266020655632, 0.010902965441346169, 0.01062423549592495, 0.00963661354035139, 0.005505301058292389]
# Time taken: 0.6042 seconds
# --------------------------------------------------------------------------------
#
# Query: Can you help me find waterproof hiking boots for men?
# Original Category: Fashion & Apparel
# Predicted Category: ['Fashion & Apparel', 'Health & Personal Care', 'Beauty', 'Tools & Home Improvement', 'Electronics', 'Sports & Outdoors', 'Books', 'Grocery', 'Home & Kitchen', 'Toys & Games']
# Predicted Scores: [0.22629320621490479, 0.184493288397789, 0.1535344421863556, 0.1182219460606575, 0.0771191418170929, 0.07523945719003677, 0.056247398257255554, 0.043670251965522766, 0.037443529814481735, 0.027737373486161232]
# Time taken: 0.6181 seconds
# --------------------------------------------------------------------------------
#
# Query: I’m looking for a warm jacket for winter that isn’t too bulky.
# Original Category: Fashion & Apparel
# Predicted Category: ['Fashion & Apparel', 'Sports & Outdoors', 'Beauty', 'Health & Personal Care', 'Electronics', 'Home & Kitchen', 'Books', 'Tools & Home Improvement', 'Toys & Games', 'Grocery']
# Predicted Scores: [0.18023304641246796, 0.17738130688667297, 0.1279359757900238, 0.10515952855348587, 0.08820005506277084, 0.0848529040813446, 0.07987566292285919, 0.06778082996606827, 0.05927737429738045, 0.029303312301635742]
# Time taken: 0.6729 seconds
# --------------------------------------------------------------------------------
#
# Query: I need a casual handbag made of leather, but not too expensive.
# Original Category: Fashion & Apparel
# Predicted Category: ['Electronics', 'Fashion & Apparel', 'Beauty', 'Home & Kitchen', 'Health & Personal Care', 'Tools & Home Improvement', 'Sports & Outdoors', 'Toys & Games', 'Books', 'Grocery']
# Predicted Scores: [0.18576394021511078, 0.1712942123413086, 0.1712353378534317, 0.11163215339183807, 0.10161054134368896, 0.08052961528301239, 0.07654931396245956, 0.04048248752951622, 0.034157831221818924, 0.026744546368718147]
# Time taken: 0.6340 seconds
# --------------------------------------------------------------------------------
#
# Query: Can you recommend organic skincare for sensitive skin?
# Original Category: Health & Personal Care
# Predicted Category: ['Health & Personal Care', 'Beauty', 'Tools & Home Improvement', 'Fashion & Apparel', 'Home & Kitchen', 'Books', 'Electronics', 'Sports & Outdoors', 'Grocery', 'Toys & Games']
# Predicted Scores: [0.5766291618347168, 0.14594891667366028, 0.06117111071944237, 0.044355545192956924, 0.04180567339062691, 0.03994577005505562, 0.030643688514828682, 0.023015394806861877, 0.019805140793323517, 0.01667957939207554]
# Time taken: 0.5863 seconds
# --------------------------------------------------------------------------------
#
# Query: I need an electric toothbrush that has a really long battery life.
# Original Category: Health & Personal Care
# Predicted Category: ['Electronics', 'Tools & Home Improvement', 'Health & Personal Care', 'Beauty', 'Home & Kitchen', 'Fashion & Apparel', 'Toys & Games', 'Sports & Outdoors', 'Grocery', 'Books']
# Predicted Scores: [0.65619957447052, 0.0917828157544136, 0.07015377283096313, 0.037674061954021454, 0.036157529801130295, 0.0266795065253973, 0.02609832026064396, 0.02209904044866562, 0.017817651852965355, 0.015337682329118252]
# Time taken: 0.6268 seconds
# --------------------------------------------------------------------------------
#
# Query: What’s the best hair dryer that works well for frizzy hair?
# Original Category: Health & Personal Care
# Predicted Category: ['Beauty', 'Tools & Home Improvement', 'Health & Personal Care', 'Fashion & Apparel', 'Home & Kitchen', 'Electronics', 'Books', 'Grocery', 'Sports & Outdoors', 'Toys & Games']
# Predicted Scores: [0.5849838852882385, 0.14206568896770477, 0.10710205137729645, 0.06611581891775131, 0.029182394966483116, 0.0197500791400671, 0.016969731077551842, 0.016480086371302605, 0.009371385909616947, 0.007978834211826324]
# Time taken: 0.6831 seconds
# --------------------------------------------------------------------------------
#
# Query: I’m looking for vegan multivitamins that are good for daily use.
# Original Category: Health & Personal Care
# Predicted Category: ['Electronics', 'Health & Personal Care', 'Tools & Home Improvement', 'Home & Kitchen', 'Beauty', 'Grocery', 'Books', 'Fashion & Apparel', 'Sports & Outdoors', 'Toys & Games']
# Predicted Scores: [0.46758291125297546, 0.27951544523239136, 0.07195765525102615, 0.05089833214879036, 0.0489765889942646, 0.02445071190595627, 0.019129138439893723, 0.015781961381435394, 0.014474824070930481, 0.007232398726046085]
# Time taken: 0.6739 seconds
# --------------------------------------------------------------------------------
#
# Query: I need a matte lipstick that lasts all day.
# Original Category: Beauty
# Predicted Category: ['Beauty', 'Health & Personal Care', 'Fashion & Apparel', 'Tools & Home Improvement', 'Electronics', 'Home & Kitchen', 'Grocery', 'Sports & Outdoors', 'Books', 'Toys & Games']
# Predicted Scores: [0.3933327794075012, 0.2097475677728653, 0.09691978991031647, 0.06849884986877441, 0.0474696159362793, 0.045278992503881454, 0.037769872695207596, 0.036982301622629166, 0.03512001410126686, 0.028880206868052483]
# Time taken: 0.5890 seconds
# --------------------------------------------------------------------------------
#
# Query: Can you recommend a good anti-aging serum?
# Original Category: Beauty
# Predicted Category: ['Beauty', 'Health & Personal Care', 'Tools & Home Improvement', 'Books', 'Home & Kitchen', 'Grocery', 'Sports & Outdoors', 'Electronics', 'Fashion & Apparel', 'Toys & Games']
# Predicted Scores: [0.26596641540527344, 0.2531296908855438, 0.1337352842092514, 0.07743670046329498, 0.058175768703222275, 0.055181633681058884, 0.052629854530096054, 0.044967204332351685, 0.03615531325340271, 0.022622179239988327]
# Time taken: 0.5772 seconds
# --------------------------------------------------------------------------------
#
# Query: I’m looking for a waterproof eyeliner that won’t smudge easily.
# Original Category: Beauty
# Predicted Category: ['Beauty', 'Health & Personal Care', 'Electronics', 'Tools & Home Improvement', 'Home & Kitchen', 'Fashion & Apparel', 'Sports & Outdoors', 'Books', 'Grocery', 'Toys & Games']
# Predicted Scores: [0.3459804654121399, 0.22190989553928375, 0.10110148042440414, 0.08303777128458023, 0.069121353328228, 0.059681110084056854, 0.04158967733383179, 0.031554412096738815, 0.025411397218704224, 0.02061241678893566]
# Time taken: 0.6806 seconds
# --------------------------------------------------------------------------------
#
# Query: What’s a good fragrance for summer that’s light and fresh?
# Original Category: Beauty
# Predicted Category: ['Beauty', 'Health & Personal Care', 'Tools & Home Improvement', 'Home & Kitchen', 'Electronics', 'Grocery', 'Books', 'Toys & Games', 'Sports & Outdoors', 'Fashion & Apparel']
# Predicted Scores: [0.8462694883346558, 0.058234862983226776, 0.029091551899909973, 0.01322665624320507, 0.011014350689947605, 0.009803029708564281, 0.009552260860800743, 0.00871686264872551, 0.008526626974344254, 0.005564352031797171]
# Time taken: 0.9279 seconds
# --------------------------------------------------------------------------------
#
# Query: I want a lightweight tent for camping with my family.
# Original Category: Sports & Outdoors
# Predicted Category: ['Sports & Outdoors', 'Beauty', 'Health & Personal Care', 'Electronics', 'Tools & Home Improvement', 'Toys & Games', 'Home & Kitchen', 'Books', 'Grocery', 'Fashion & Apparel']
# Predicted Scores: [0.2026216983795166, 0.16536569595336914, 0.1291813999414444, 0.11681805551052094, 0.09570851176977158, 0.0776694193482399, 0.06987398117780685, 0.05500324070453644, 0.044981323182582855, 0.04277661070227623]
# Time taken: 0.8722 seconds
# --------------------------------------------------------------------------------
#
# Query: What’s a good mountain bike for a beginner?
# Original Category: Sports & Outdoors
# Predicted Category: ['Beauty', 'Sports & Outdoors', 'Health & Personal Care', 'Books', 'Tools & Home Improvement', 'Electronics', 'Grocery', 'Home & Kitchen', 'Fashion & Apparel', 'Toys & Games']
# Predicted Scores: [0.2932508587837219, 0.18133361637592316, 0.131068617105484, 0.0854174867272377, 0.07688505202531815, 0.06212106719613075, 0.05188777670264244, 0.04575788229703903, 0.0408780612051487, 0.03139961510896683]
# Time taken: 0.9291 seconds
# --------------------------------------------------------------------------------
#
# Query: Can you recommend a yoga mat that’s comfortable for home workouts?
# Original Category: Sports & Outdoors
# Predicted Category: ['Health & Personal Care', 'Beauty', 'Tools & Home Improvement', 'Sports & Outdoors', 'Grocery', 'Home & Kitchen', 'Books', 'Fashion & Apparel', 'Electronics', 'Toys & Games']
# Predicted Scores: [0.2130274772644043, 0.19260922074317932, 0.17388640344142914, 0.14318034052848816, 0.058670926839113235, 0.04908326268196106, 0.04671572893857956, 0.046439748257398605, 0.04189963638782501, 0.03448724001646042]
# Time taken: 1.0268 seconds
# --------------------------------------------------------------------------------
#
# Query: I need a backpack that’s waterproof and great for hiking.
# Original Category: Sports & Outdoors
# Predicted Category: ['Health & Personal Care', 'Tools & Home Improvement', 'Beauty', 'Electronics', 'Sports & Outdoors', 'Fashion & Apparel', 'Grocery', 'Toys & Games', 'Books', 'Home & Kitchen']
# Predicted Scores: [0.386201947927475, 0.1411197930574417, 0.11753981560468674, 0.11166863143444061, 0.08396119624376297, 0.067609503865242, 0.024346115067601204, 0.02279812842607498, 0.02249157801270485, 0.022263245657086372]
# Time taken: 0.6737 seconds
# --------------------------------------------------------------------------------
#
# Query: I’m looking for an educational toy for my 5-year-old.
# Original Category: Toys & Games
# Predicted Category: ['Toys & Games', 'Beauty', 'Electronics', 'Books', 'Tools & Home Improvement', 'Health & Personal Care', 'Grocery', 'Sports & Outdoors', 'Home & Kitchen', 'Fashion & Apparel']
# Predicted Scores: [0.2752645015716553, 0.22868399322032928, 0.1142878606915474, 0.06825637817382812, 0.06782938539981842, 0.05994584038853645, 0.05569300428032875, 0.049534205347299576, 0.047596171498298645, 0.03290858864784241]
# Time taken: 0.6515 seconds
# --------------------------------------------------------------------------------
#
# Query: What’s a good board game for playing with the whole family?
# Original Category: Toys & Games
# Predicted Category: ['Tools & Home Improvement', 'Toys & Games', 'Beauty', 'Health & Personal Care', 'Sports & Outdoors', 'Electronics', 'Grocery', 'Fashion & Apparel', 'Books', 'Home & Kitchen']
# Predicted Scores: [0.17409563064575195, 0.16232265532016754, 0.1510731726884842, 0.08572063595056534, 0.08159493654966354, 0.08071892708539963, 0.07970971614122391, 0.06708726286888123, 0.06134512275457382, 0.056331899017095566]
# Time taken: 0.6339 seconds
# --------------------------------------------------------------------------------
#
# Query: My son loves remote control cars. Any recommendations?
# Original Category: Toys & Games
# Predicted Category: ['Electronics', 'Beauty', 'Tools & Home Improvement', 'Health & Personal Care', 'Toys & Games', 'Sports & Outdoors', 'Grocery', 'Home & Kitchen', 'Books', 'Fashion & Apparel']
# Predicted Scores: [0.42327019572257996, 0.40077054500579834, 0.047270793467760086, 0.02775641903281212, 0.027575137093663216, 0.01951725035905838, 0.014588809572160244, 0.013945839367806911, 0.012855678796768188, 0.012449358589947224]
# Time taken: 0.5849 seconds
# --------------------------------------------------------------------------------
#
# Query: I need some fun water toys for my kids to play with outside this summer.
# Original Category: Toys & Games
# Predicted Category: ['Toys & Games', 'Beauty', 'Sports & Outdoors', 'Tools & Home Improvement', 'Health & Personal Care', 'Home & Kitchen', 'Grocery', 'Electronics', 'Books', 'Fashion & Apparel']
# Predicted Scores: [0.8455005884170532, 0.04213552922010422, 0.034825194627046585, 0.020289277657866478, 0.015482614748179913, 0.011748348362743855, 0.010346142575144768, 0.007472107652574778, 0.007470536511391401, 0.004729692358523607]
# Time taken: 0.6577 seconds
# --------------------------------------------------------------------------------
#
# Query: Can you recommend a good thriller with a female lead?
# Original Category: Books
# Predicted Category: ['Books', 'Beauty', 'Electronics', 'Health & Personal Care', 'Home & Kitchen', 'Sports & Outdoors', 'Grocery', 'Tools & Home Improvement', 'Fashion & Apparel', 'Toys & Games']
# Predicted Scores: [0.3484649956226349, 0.10654880851507187, 0.07706813514232635, 0.07410135865211487, 0.07357591390609741, 0.07263209670782089, 0.07122525572776794, 0.06337562948465347, 0.058011721819639206, 0.054996099323034286]
# Time taken: 0.6204 seconds
# --------------------------------------------------------------------------------
#
# Query: What’s a good book about productivity?
# Original Category: Books
# Predicted Category: ['Books', 'Tools & Home Improvement', 'Health & Personal Care', 'Beauty', 'Home & Kitchen', 'Grocery', 'Electronics', 'Fashion & Apparel', 'Toys & Games', 'Sports & Outdoors']
# Predicted Scores: [0.9549858570098877, 0.01299582701176405, 0.007761955726891756, 0.006708610337227583, 0.006233213469386101, 0.0032611654605716467, 0.0026374999433755875, 0.0019807727076113224, 0.001850026659667492, 0.0015850623603910208]
# Time taken: 0.5689 seconds
# --------------------------------------------------------------------------------
#
# Query: I’m looking for a fantasy series for young adults. Any suggestions?
# Original Category: Books
# Predicted Category: ['Books', 'Tools & Home Improvement', 'Health & Personal Care', 'Beauty', 'Electronics', 'Grocery', 'Home & Kitchen', 'Toys & Games', 'Fashion & Apparel', 'Sports & Outdoors']
# Predicted Scores: [0.22439365088939667, 0.15816561877727509, 0.11242453008890152, 0.08921828120946884, 0.08772365748882294, 0.08185406774282455, 0.07284067571163177, 0.06904148310422897, 0.05699925124645233, 0.04733874276280403]
# Time taken: 0.6590 seconds
# --------------------------------------------------------------------------------
#
# Query: Can you recommend a picture book with animals for kids?
# Original Category: Books
# Predicted Category: ['Books', 'Beauty', 'Toys & Games', 'Health & Personal Care', 'Tools & Home Improvement', 'Grocery', 'Sports & Outdoors', 'Electronics', 'Home & Kitchen', 'Fashion & Apparel']
# Predicted Scores: [0.8430609107017517, 0.04796880483627319, 0.027176981791853905, 0.02414909563958645, 0.011125355027616024, 0.010636319406330585, 0.009418184868991375, 0.009257704950869083, 0.009140740148723125, 0.008065935224294662]
# Time taken: 0.5939 seconds
# --------------------------------------------------------------------------------
#
# Query: I need a cordless drill for some DIY projects around the house.
# Original Category: Tools & Home Improvement
# Predicted Category: ['Tools & Home Improvement', 'Electronics', 'Fashion & Apparel', 'Toys & Games', 'Home & Kitchen', 'Sports & Outdoors', 'Health & Personal Care', 'Beauty', 'Grocery', 'Books']
# Predicted Scores: [0.6240293979644775, 0.16046319901943207, 0.05165998265147209, 0.0475977398455143, 0.028058499097824097, 0.027002278715372086, 0.022455265745520592, 0.021456290036439896, 0.008873434737324715, 0.008403959684073925]
# Time taken: 0.6439 seconds
# --------------------------------------------------------------------------------
#
# Query: What’s a good smart thermostat that will help save on energy?
# Original Category: Tools & Home Improvement
# Predicted Category: ['Electronics', 'Tools & Home Improvement', 'Health & Personal Care', 'Beauty', 'Home & Kitchen', 'Grocery', 'Books', 'Fashion & Apparel', 'Toys & Games', 'Sports & Outdoors']
# Predicted Scores: [0.9810038208961487, 0.00850216206163168, 0.004167011473327875, 0.0016306187026202679, 0.0009709607111290097, 0.0009022175800055265, 0.0008900395478121936, 0.0007701129652559757, 0.0006298563093878329, 0.0005331548163667321]
# Time taken: 0.6855 seconds
# --------------------------------------------------------------------------------
#
# Query: I’m looking for power tools for woodwork. Any recommendations?
# Original Category: Tools & Home Improvement
# Predicted Category: ['Tools & Home Improvement', 'Beauty', 'Home & Kitchen', 'Fashion & Apparel', 'Books', 'Electronics', 'Grocery', 'Toys & Games', 'Sports & Outdoors', 'Health & Personal Care']
# Predicted Scores: [0.9137735962867737, 0.01921745203435421, 0.010149159468710423, 0.009793777950108051, 0.009476596489548683, 0.008768212050199509, 0.008565743453800678, 0.0076928818598389626, 0.006331493612378836, 0.006231121718883514]
# Time taken: 0.6204 seconds
# --------------------------------------------------------------------------------
#
# Query: I want solar-powered lights for my garden.
# Original Category: Tools & Home Improvement
# Predicted Category: ['Electronics', 'Beauty', 'Home & Kitchen', 'Tools & Home Improvement', 'Health & Personal Care', 'Grocery', 'Books', 'Fashion & Apparel', 'Toys & Games', 'Sports & Outdoors']
# Predicted Scores: [0.843204140663147, 0.04354983568191528, 0.029512636363506317, 0.02819751389324665, 0.01989593543112278, 0.008632027544081211, 0.007325162645429373, 0.0068887039087712765, 0.0066002835519611835, 0.0061938087455928326]
# Time taken: 0.5834 seconds
# --------------------------------------------------------------------------------
#
# Query: Can you recommend some gluten-free snacks for kids?
# Original Category: Grocery
# Predicted Category: ['Health & Personal Care', 'Tools & Home Improvement', 'Home & Kitchen', 'Toys & Games', 'Electronics', 'Beauty', 'Grocery', 'Books', 'Sports & Outdoors', 'Fashion & Apparel']
# Predicted Scores: [0.27170276641845703, 0.17847271263599396, 0.07580636441707611, 0.07538621872663498, 0.07154807448387146, 0.07120808959007263, 0.07007303088903427, 0.06691767275333405, 0.0609159879386425, 0.05796902999281883]
# Time taken: 0.6245 seconds
# --------------------------------------------------------------------------------
#
# Query: I need keto-friendly ingredients for baking at home.
# Original Category: Grocery
# Predicted Category: ['Home & Kitchen', 'Beauty', 'Tools & Home Improvement', 'Health & Personal Care', 'Grocery', 'Electronics', 'Sports & Outdoors', 'Fashion & Apparel', 'Books', 'Toys & Games']
# Predicted Scores: [0.9179620146751404, 0.0274303387850523, 0.018697500228881836, 0.007690452039241791, 0.005650932900607586, 0.005617634858936071, 0.0048611341044306755, 0.00455322815105319, 0.004026476293802261, 0.003510287031531334]
# Time taken: 0.6111 seconds
# --------------------------------------------------------------------------------
#
# Query: What’s the best organic coffee for brewing at home?
# Original Category: Grocery
# Predicted Category: ['Home & Kitchen', 'Beauty', 'Tools & Home Improvement', 'Health & Personal Care', 'Electronics', 'Grocery', 'Fashion & Apparel', 'Books', 'Sports & Outdoors', 'Toys & Games']
# Predicted Scores: [0.5551928281784058, 0.19926142692565918, 0.07448337972164154, 0.042943987995386124, 0.02465214766561985, 0.023124756291508675, 0.02310870960354805, 0.020322702825069427, 0.019778862595558167, 0.01713109202682972]
# Time taken: 0.7503 seconds
# --------------------------------------------------------------------------------
#
# Query: What are some good dairy-free milk alternatives?
# Original Category: Grocery
# Predicted Category: ['Health & Personal Care', 'Beauty', 'Tools & Home Improvement', 'Grocery', 'Home & Kitchen', 'Fashion & Apparel', 'Electronics', 'Sports & Outdoors', 'Books', 'Toys & Games']
# Predicted Scores: [0.48300352692604065, 0.1504826545715332, 0.12645459175109863, 0.042406924068927765, 0.03762039914727211, 0.03661266714334488, 0.03513351455330849, 0.03001648746430874, 0.0293419249355793, 0.028927283361554146]
# Time taken: 1.4288 seconds
# --------------------------------------------------------------------------------
#
# Average Time per Query: 0.7174 seconds
# Top-1 Accuracy: 0.5750
# Top-3 Accuracy: 0.7500
# Precision: 0.6364, Recall: 0.5750, F1-Score: 0.5529
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# [0.575, 30, 0.6363636363636365, 0.575, 0.5528571428571429]

# %% [markdown]
# # Zero shot classification with MoritzLaurer/mDeBERTa-v3-base-mnli-xnli

# %%
from transformers import pipeline

classifier_mdeberta = pipeline("zero-shot-classification", model='MoritzLaurer/mDeBERTa-v3-base-mnli-xnli')

# %%
# Main function to run classification and evaluation
def main(queries_with_categories, candidate_labels, classifier):
    # Run the classification
    results = run_classification(queries_with_categories, candidate_labels, classifier)

    # Evaluate the predictions
    evaluation_metrics = evaluate_predictions(results)
    return evaluation_metrics


# Call the main function
main(queries_with_categories, candidate_labels, classifier_mdeberta)
# Out:
# Query: I need a phone with a really good camera for under $500.
# Original Category: Electronics
# Predicted Category: ['Electronics', 'Health & Personal Care', 'Fashion & Apparel', 'Sports & Outdoors', 'Tools & Home Improvement', 'Beauty', 'Grocery', 'Home & Kitchen', 'Toys & Games', 'Books']
# Predicted Scores: [0.5835335850715637, 0.06371399015188217, 0.060272786766290665, 0.05692867189645767, 0.05061699450016022, 0.04326498135924339, 0.04170524701476097, 0.04060068726539612, 0.03484542667865753, 0.024517685174942017]
# Time taken: 6.7317 seconds
# --------------------------------------------------------------------------------
#
# Query: What’s the best wireless headset for working from home?
# Original Category: Electronics
# Predicted Category: ['Electronics', 'Tools & Home Improvement', 'Health & Personal Care', 'Fashion & Apparel', 'Home & Kitchen', 'Sports & Outdoors', 'Toys & Games', 'Grocery', 'Books', 'Beauty']
# Predicted Scores: [0.3935095965862274, 0.130445197224617, 0.12060186266899109, 0.08467406034469604, 0.06512704491615295, 0.053879790008068085, 0.04669184982776642, 0.04143421724438667, 0.037879686802625656, 0.02575673535466194]
# Time taken: 3.6285 seconds
# --------------------------------------------------------------------------------
#
# Query: Can you suggest a smartwatch that works with iPhones?
# Original Category: Electronics
# Predicted Category: ['Electronics', 'Sports & Outdoors', 'Health & Personal Care', 'Fashion & Apparel', 'Tools & Home Improvement', 'Toys & Games', 'Home & Kitchen', 'Books', 'Grocery', 'Beauty']
# Predicted Scores: [0.7150140404701233, 0.05309852212667465, 0.0501568540930748, 0.0396759957075119, 0.033660441637039185, 0.027184342965483665, 0.024023642763495445, 0.02170618809759617, 0.01931438036262989, 0.016165535897016525]
# Time taken: 4.0725 seconds
# --------------------------------------------------------------------------------
#
# Query: I’m looking for a TV that has both 4K and Dolby Vision support.
# Original Category: Electronics
# Predicted Category: ['Electronics', 'Fashion & Apparel', 'Health & Personal Care', 'Grocery', 'Sports & Outdoors', 'Home & Kitchen', 'Beauty', 'Toys & Games', 'Books', 'Tools & Home Improvement']
# Predicted Scores: [0.4132694900035858, 0.09518846124410629, 0.08680076897144318, 0.08228198438882828, 0.060648102313280106, 0.059576764702796936, 0.05840316414833069, 0.05821708217263222, 0.04624712094664574, 0.039366982877254486]
# Time taken: 4.6453 seconds
# --------------------------------------------------------------------------------
#
# Query: I want a set of non-stick pans that last long and are easy to clean.
# Original Category: Home & Kitchen
# Predicted Category: ['Home & Kitchen', 'Tools & Home Improvement', 'Electronics', 'Sports & Outdoors', 'Fashion & Apparel', 'Health & Personal Care', 'Grocery', 'Beauty', 'Toys & Games', 'Books']
# Predicted Scores: [0.24435701966285706, 0.2364899218082428, 0.0932987704873085, 0.089074045419693, 0.08487112075090408, 0.06548027694225311, 0.05923696234822273, 0.05222669243812561, 0.04950879514217377, 0.025456279516220093]
# Time taken: 3.7717 seconds
# --------------------------------------------------------------------------------
#
# Query: What’s the best air purifier to help with allergies?
# Original Category: Home & Kitchen
# Predicted Category: ['Health & Personal Care', 'Electronics', 'Tools & Home Improvement', 'Home & Kitchen', 'Sports & Outdoors', 'Fashion & Apparel', 'Toys & Games', 'Books', 'Grocery', 'Beauty']
# Predicted Scores: [0.22816844284534454, 0.18285919725894928, 0.09948168694972992, 0.09770513325929642, 0.09511104971170425, 0.09293971210718155, 0.05591026321053505, 0.054140832275152206, 0.051865510642528534, 0.04181816428899765]
# Time taken: 3.6029 seconds
# --------------------------------------------------------------------------------
#
# Query: I’m looking for a vacuum cleaner that works well for picking up pet hair.
# Original Category: Home & Kitchen
# Predicted Category: ['Tools & Home Improvement', 'Health & Personal Care', 'Electronics', 'Home & Kitchen', 'Fashion & Apparel', 'Beauty', 'Sports & Outdoors', 'Books', 'Toys & Games', 'Grocery']
# Predicted Scores: [0.18043507635593414, 0.16122010350227356, 0.13195914030075073, 0.10997626185417175, 0.09659254550933838, 0.09041811525821686, 0.07866362482309341, 0.05134537070989609, 0.05120444297790527, 0.048185352236032486]
# Time taken: 5.3248 seconds
# --------------------------------------------------------------------------------
#
# Query: Can you recommend a fridge that’s energy-efficient and has smart features?
# Original Category: Home & Kitchen
# Predicted Category: ['Electronics', 'Home & Kitchen', 'Grocery', 'Health & Personal Care', 'Tools & Home Improvement', 'Fashion & Apparel', 'Sports & Outdoors', 'Books', 'Toys & Games', 'Beauty']
# Predicted Scores: [0.3271719813346863, 0.21100957691669464, 0.10663171857595444, 0.10536887496709824, 0.07117200642824173, 0.05504085496068001, 0.043257273733615875, 0.028916362673044205, 0.027870124205946922, 0.02356124483048916]
# Time taken: 3.7403 seconds
# --------------------------------------------------------------------------------
#
# Query: I want a blue dress for summer that’s comfortable.
# Original Category: Fashion & Apparel
# Predicted Category: ['Fashion & Apparel', 'Beauty', 'Health & Personal Care', 'Sports & Outdoors', 'Home & Kitchen', 'Electronics', 'Books', 'Grocery', 'Toys & Games', 'Tools & Home Improvement']
# Predicted Scores: [0.42049700021743774, 0.1689981073141098, 0.08462602645158768, 0.07883346080780029, 0.051489848643541336, 0.05090386047959328, 0.041614264249801636, 0.03738080710172653, 0.037282902747392654, 0.02837369777262211]
# Time taken: 3.5690 seconds
# --------------------------------------------------------------------------------
#
# Query: Can you help me find waterproof hiking boots for men?
# Original Category: Fashion & Apparel
# Predicted Category: ['Sports & Outdoors', 'Fashion & Apparel', 'Health & Personal Care', 'Electronics', 'Tools & Home Improvement', 'Toys & Games', 'Books', 'Home & Kitchen', 'Grocery', 'Beauty']
# Predicted Scores: [0.353241503238678, 0.176091730594635, 0.11013241112232208, 0.0882696732878685, 0.07962189614772797, 0.07439368963241577, 0.03692581504583359, 0.030700281262397766, 0.02871531806886196, 0.021907707676291466]
# Time taken: 4.9010 seconds
# --------------------------------------------------------------------------------
#
# Query: I’m looking for a warm jacket for winter that isn’t too bulky.
# Original Category: Fashion & Apparel
# Predicted Category: ['Fashion & Apparel', 'Sports & Outdoors', 'Health & Personal Care', 'Home & Kitchen', 'Tools & Home Improvement', 'Electronics', 'Toys & Games', 'Beauty', 'Grocery', 'Books']
# Predicted Scores: [0.24421542882919312, 0.1241505891084671, 0.11533379554748535, 0.09317442774772644, 0.0861978605389595, 0.08495604991912842, 0.07981840521097183, 0.06535617262125015, 0.06108683720231056, 0.045710377395153046]
# Time taken: 3.9050 seconds
# --------------------------------------------------------------------------------
#
# Query: I need a casual handbag made of leather, but not too expensive.
# Original Category: Fashion & Apparel
# Predicted Category: ['Fashion & Apparel', 'Health & Personal Care', 'Home & Kitchen', 'Beauty', 'Sports & Outdoors', 'Grocery', 'Toys & Games', 'Books', 'Electronics', 'Tools & Home Improvement']
# Predicted Scores: [0.23267750442028046, 0.166741743683815, 0.12240771949291229, 0.1004299446940422, 0.08493941277265549, 0.07347819954156876, 0.0708766058087349, 0.05568322166800499, 0.04930059239268303, 0.043465010821819305]
# Time taken: 3.6512 seconds
# --------------------------------------------------------------------------------
#
# Query: Can you recommend organic skincare for sensitive skin?
# Original Category: Health & Personal Care
# Predicted Category: ['Beauty', 'Health & Personal Care', 'Home & Kitchen', 'Fashion & Apparel', 'Grocery', 'Books', 'Electronics', 'Sports & Outdoors', 'Toys & Games', 'Tools & Home Improvement']
# Predicted Scores: [0.30105990171432495, 0.20775814354419708, 0.08030597120523453, 0.0777219608426094, 0.07435790449380875, 0.05790495499968529, 0.051218144595623016, 0.05034276098012924, 0.05013851076364517, 0.04919184371829033]
# Time taken: 3.9984 seconds
# --------------------------------------------------------------------------------
#
# Query: I need an electric toothbrush that has a really long battery life.
# Original Category: Health & Personal Care
# Predicted Category: ['Electronics', 'Health & Personal Care', 'Tools & Home Improvement', 'Beauty', 'Home & Kitchen', 'Fashion & Apparel', 'Sports & Outdoors', 'Grocery', 'Books', 'Toys & Games']
# Predicted Scores: [0.452604740858078, 0.20114432275295258, 0.12636138498783112, 0.0807419940829277, 0.037798814475536346, 0.02487213909626007, 0.023386212065815926, 0.019792465493083, 0.0180970449000597, 0.015200858004391193]
# Time taken: 4.6113 seconds
# --------------------------------------------------------------------------------
#
# Query: What’s the best hair dryer that works well for frizzy hair?
# Original Category: Health & Personal Care
# Predicted Category: ['Fashion & Apparel', 'Electronics', 'Health & Personal Care', 'Tools & Home Improvement', 'Beauty', 'Home & Kitchen', 'Sports & Outdoors', 'Books', 'Toys & Games', 'Grocery']
# Predicted Scores: [0.14681923389434814, 0.14631250500679016, 0.14002352952957153, 0.11752165853977203, 0.11661727726459503, 0.09205405414104462, 0.08266586065292358, 0.06330329179763794, 0.05435482785105705, 0.040327753871679306]
# Time taken: 3.6486 seconds
# --------------------------------------------------------------------------------
#
# Query: I’m looking for vegan multivitamins that are good for daily use.
# Original Category: Health & Personal Care
# Predicted Category: ['Health & Personal Care', 'Home & Kitchen', 'Fashion & Apparel', 'Grocery', 'Beauty', 'Electronics', 'Sports & Outdoors', 'Toys & Games', 'Tools & Home Improvement', 'Books']
# Predicted Scores: [0.24926619231700897, 0.15073145925998688, 0.11640913039445877, 0.08547352999448776, 0.07246815413236618, 0.07094485312700272, 0.06935252249240875, 0.06426732987165451, 0.06277482956647873, 0.05831199884414673]
# Time taken: 3.7308 seconds
# --------------------------------------------------------------------------------
#
# Query: I need a matte lipstick that lasts all day.
# Original Category: Beauty
# Predicted Category: ['Beauty', 'Fashion & Apparel', 'Health & Personal Care', 'Home & Kitchen', 'Electronics', 'Toys & Games', 'Grocery', 'Sports & Outdoors', 'Books', 'Tools & Home Improvement']
# Predicted Scores: [0.6063642501831055, 0.07537922263145447, 0.06717786937952042, 0.04437877982854843, 0.04010834917426109, 0.038851939141750336, 0.0388188399374485, 0.038391534239053726, 0.026312287896871567, 0.024216916412115097]
# Time taken: 4.8057 seconds
# --------------------------------------------------------------------------------
#
# Query: Can you recommend a good anti-aging serum?
# Original Category: Beauty
# Predicted Category: ['Health & Personal Care', 'Beauty', 'Fashion & Apparel', 'Home & Kitchen', 'Electronics', 'Sports & Outdoors', 'Tools & Home Improvement', 'Toys & Games', 'Books', 'Grocery']
# Predicted Scores: [0.2319539338350296, 0.1497473418712616, 0.1359240710735321, 0.08571413904428482, 0.08427989482879639, 0.0803576111793518, 0.07335368543863297, 0.07190516591072083, 0.04960112273693085, 0.037162989377975464]
# Time taken: 3.5265 seconds
# --------------------------------------------------------------------------------
#
# Query: I’m looking for a waterproof eyeliner that won’t smudge easily.
# Original Category: Beauty
# Predicted Category: ['Beauty', 'Fashion & Apparel', 'Health & Personal Care', 'Electronics', 'Sports & Outdoors', 'Home & Kitchen', 'Toys & Games', 'Grocery', 'Books', 'Tools & Home Improvement']
# Predicted Scores: [0.47467097640037537, 0.09442281723022461, 0.0763910785317421, 0.058481648564338684, 0.05837974324822426, 0.0574963241815567, 0.05080003663897514, 0.047543782740831375, 0.04709865525364876, 0.03471491485834122]
# Time taken: 3.8645 seconds
# --------------------------------------------------------------------------------
#
# Query: What’s a good fragrance for summer that’s light and fresh?
# Original Category: Beauty
# Predicted Category: ['Sports & Outdoors', 'Health & Personal Care', 'Fashion & Apparel', 'Beauty', 'Home & Kitchen', 'Books', 'Toys & Games', 'Tools & Home Improvement', 'Grocery', 'Electronics']
# Predicted Scores: [0.15354084968566895, 0.14719301462173462, 0.12748877704143524, 0.11242083460092545, 0.10882645100355148, 0.08058714866638184, 0.07942771166563034, 0.0671539157629013, 0.0623907707631588, 0.06097051501274109]
# Time taken: 5.0328 seconds
# --------------------------------------------------------------------------------
#
# Query: I want a lightweight tent for camping with my family.
# Original Category: Sports & Outdoors
# Predicted Category: ['Sports & Outdoors', 'Fashion & Apparel', 'Health & Personal Care', 'Electronics', 'Tools & Home Improvement', 'Grocery', 'Toys & Games', 'Home & Kitchen', 'Books', 'Beauty']
# Predicted Scores: [0.2011723816394806, 0.19272266328334808, 0.11770518869161606, 0.11301267147064209, 0.07173514366149902, 0.07139730453491211, 0.0675441175699234, 0.06352680921554565, 0.052165739238262177, 0.049017950892448425]
# Time taken: 3.5596 seconds
# --------------------------------------------------------------------------------
#
# Query: What’s a good mountain bike for a beginner?
# Original Category: Sports & Outdoors
# Predicted Category: ['Sports & Outdoors', 'Health & Personal Care', 'Home & Kitchen', 'Fashion & Apparel', 'Toys & Games', 'Electronics', 'Tools & Home Improvement', 'Books', 'Grocery', 'Beauty']
# Predicted Scores: [0.6156003475189209, 0.05861816555261612, 0.05321721360087395, 0.05193347483873367, 0.048716749995946884, 0.042261313647031784, 0.03890906274318695, 0.037742726504802704, 0.035921018570661545, 0.017079971730709076]
# Time taken: 3.5814 seconds
# --------------------------------------------------------------------------------
#
# Query: Can you recommend a yoga mat that’s comfortable for home workouts?
# Original Category: Sports & Outdoors
# Predicted Category: ['Sports & Outdoors', 'Health & Personal Care', 'Fashion & Apparel', 'Tools & Home Improvement', 'Home & Kitchen', 'Electronics', 'Toys & Games', 'Grocery', 'Beauty', 'Books']
# Predicted Scores: [0.21587379276752472, 0.17691421508789062, 0.1327415108680725, 0.1064959168434143, 0.08549794554710388, 0.07316097617149353, 0.0632324069738388, 0.05663634464144707, 0.04824448749423027, 0.041202396154403687]
# Time taken: 4.2428 seconds
# --------------------------------------------------------------------------------
#
# Query: I need a backpack that’s waterproof and great for hiking.
# Original Category: Sports & Outdoors
# Predicted Category: ['Sports & Outdoors', 'Health & Personal Care', 'Fashion & Apparel', 'Electronics', 'Home & Kitchen', 'Toys & Games', 'Tools & Home Improvement', 'Grocery', 'Beauty', 'Books']
# Predicted Scores: [0.4446471035480499, 0.12718085944652557, 0.12676560878753662, 0.05831969156861305, 0.05543268099427223, 0.044528622180223465, 0.04078283533453941, 0.03924481198191643, 0.03239329904317856, 0.030704516917467117]
# Time taken: 4.5275 seconds
# --------------------------------------------------------------------------------
#
# Query: I’m looking for an educational toy for my 5-year-old.
# Original Category: Toys & Games
# Predicted Category: ['Toys & Games', 'Sports & Outdoors', 'Electronics', 'Health & Personal Care', 'Fashion & Apparel', 'Home & Kitchen', 'Tools & Home Improvement', 'Books', 'Grocery', 'Beauty']
# Predicted Scores: [0.24848231673240662, 0.11025451123714447, 0.10468622297048569, 0.0925074964761734, 0.09231413155794144, 0.07933416962623596, 0.07799267023801804, 0.07495701313018799, 0.07287587225437164, 0.046595606952905655]
# Time taken: 3.6854 seconds
# --------------------------------------------------------------------------------
#
# Query: What’s a good board game for playing with the whole family?
# Original Category: Toys & Games
# Predicted Category: ['Toys & Games', 'Sports & Outdoors', 'Health & Personal Care', 'Fashion & Apparel', 'Home & Kitchen', 'Grocery', 'Tools & Home Improvement', 'Books', 'Electronics', 'Beauty']
# Predicted Scores: [0.4004915952682495, 0.19543424248695374, 0.09707554429769516, 0.053693149238824844, 0.0514954999089241, 0.047051891684532166, 0.040742177516222, 0.04033046215772629, 0.03883985057473183, 0.034845542162656784]
# Time taken: 3.6725 seconds
# --------------------------------------------------------------------------------
#
# Query: My son loves remote control cars. Any recommendations?
# Original Category: Toys & Games
# Predicted Category: ['Electronics', 'Health & Personal Care', 'Sports & Outdoors', 'Toys & Games', 'Beauty', 'Fashion & Apparel', 'Tools & Home Improvement', 'Home & Kitchen', 'Books', 'Grocery']
# Predicted Scores: [0.631218671798706, 0.10349109768867493, 0.04894022271037102, 0.048451002687215805, 0.03912828490138054, 0.038074951618909836, 0.033900316804647446, 0.02138599567115307, 0.018322477117180824, 0.017086928710341454]
# Time taken: 4.7989 seconds
# --------------------------------------------------------------------------------
#
# Query: I need some fun water toys for my kids to play with outside this summer.
# Original Category: Toys & Games
# Predicted Category: ['Toys & Games', 'Sports & Outdoors', 'Health & Personal Care', 'Tools & Home Improvement', 'Fashion & Apparel', 'Home & Kitchen', 'Electronics', 'Grocery', 'Beauty', 'Books']
# Predicted Scores: [0.3472526967525482, 0.32033777236938477, 0.07839570194482803, 0.07095314562320709, 0.07066444307565689, 0.03138338029384613, 0.02980039268732071, 0.021611355245113373, 0.018657738342881203, 0.01094338670372963]
# Time taken: 3.6615 seconds
# --------------------------------------------------------------------------------
#
# Query: Can you recommend a good thriller with a female lead?
# Original Category: Books
# Predicted Category: ['Books', 'Fashion & Apparel', 'Toys & Games', 'Health & Personal Care', 'Beauty', 'Electronics', 'Tools & Home Improvement', 'Sports & Outdoors', 'Home & Kitchen', 'Grocery']
# Predicted Scores: [0.26572364568710327, 0.12726332247257233, 0.10351459681987762, 0.0929325520992279, 0.08594177663326263, 0.07804498076438904, 0.07625305652618408, 0.06140843778848648, 0.06019248440861702, 0.04872515797615051]
# Time taken: 3.6356 seconds
# --------------------------------------------------------------------------------
#
# Query: What’s a good book about productivity?
# Original Category: Books
# Predicted Category: ['Books', 'Health & Personal Care', 'Tools & Home Improvement', 'Home & Kitchen', 'Sports & Outdoors', 'Fashion & Apparel', 'Electronics', 'Toys & Games', 'Grocery', 'Beauty']
# Predicted Scores: [0.6966394186019897, 0.05021325498819351, 0.04391568526625633, 0.03986058011651039, 0.036297693848609924, 0.03247147053480148, 0.03224586695432663, 0.024892771616578102, 0.022913293913006783, 0.020550040528178215]
# Time taken: 4.7021 seconds
# --------------------------------------------------------------------------------
#
# Query: I’m looking for a fantasy series for young adults. Any suggestions?
# Original Category: Books
# Predicted Category: ['Toys & Games', 'Books', 'Health & Personal Care', 'Fashion & Apparel', 'Sports & Outdoors', 'Electronics', 'Grocery', 'Tools & Home Improvement', 'Beauty', 'Home & Kitchen']
# Predicted Scores: [0.43884119391441345, 0.19479900598526, 0.07104230672121048, 0.0592041090130806, 0.05153297260403633, 0.043742455542087555, 0.04176986217498779, 0.03752077743411064, 0.032464344054460526, 0.029082925990223885]
# Time taken: 4.0227 seconds
# --------------------------------------------------------------------------------
#
# Query: Can you recommend a picture book with animals for kids?
# Original Category: Books
# Predicted Category: ['Books', 'Toys & Games', 'Health & Personal Care', 'Sports & Outdoors', 'Fashion & Apparel', 'Home & Kitchen', 'Tools & Home Improvement', 'Electronics', 'Grocery', 'Beauty']
# Predicted Scores: [0.6678745746612549, 0.11314667016267776, 0.04858138784766197, 0.04275311902165413, 0.029782740399241447, 0.02152184024453163, 0.02100316248834133, 0.020834099501371384, 0.01836218498647213, 0.016140149906277657]
# Time taken: 3.5611 seconds
# --------------------------------------------------------------------------------
#
# Query: I need a cordless drill for some DIY projects around the house.
# Original Category: Tools & Home Improvement
# Predicted Category: ['Tools & Home Improvement', 'Electronics', 'Toys & Games', 'Sports & Outdoors', 'Home & Kitchen', 'Health & Personal Care', 'Fashion & Apparel', 'Grocery', 'Beauty', 'Books']
# Predicted Scores: [0.3682488203048706, 0.2582014203071594, 0.08141885697841644, 0.07348104566335678, 0.052038032561540604, 0.04547368735074997, 0.03944353014230728, 0.034194640815258026, 0.026499144732952118, 0.021000832319259644]
# Time taken: 4.0421 seconds
# --------------------------------------------------------------------------------
#
# Query: What’s a good smart thermostat that will help save on energy?
# Original Category: Tools & Home Improvement
# Predicted Category: ['Electronics', 'Home & Kitchen', 'Health & Personal Care', 'Tools & Home Improvement', 'Fashion & Apparel', 'Sports & Outdoors', 'Books', 'Grocery', 'Toys & Games', 'Beauty']
# Predicted Scores: [0.3091028332710266, 0.16768115758895874, 0.13165758550167084, 0.09915953874588013, 0.08374971151351929, 0.04896552488207817, 0.046196527779102325, 0.04154147580265999, 0.03979243338108063, 0.03215312957763672]
# Time taken: 4.7736 seconds
# --------------------------------------------------------------------------------
#
# Query: I’m looking for power tools for woodwork. Any recommendations?
# Original Category: Tools & Home Improvement
# Predicted Category: ['Tools & Home Improvement', 'Health & Personal Care', 'Sports & Outdoors', 'Home & Kitchen', 'Electronics', 'Fashion & Apparel', 'Grocery', 'Toys & Games', 'Beauty', 'Books']
# Predicted Scores: [0.42639851570129395, 0.09473107010126114, 0.09132029116153717, 0.07082770764827728, 0.06455972790718079, 0.06306510418653488, 0.05311305820941925, 0.05190237984061241, 0.04997266083955765, 0.0341094471514225]
# Time taken: 3.6451 seconds
# --------------------------------------------------------------------------------
#
# Query: I want solar-powered lights for my garden.
# Original Category: Tools & Home Improvement
# Predicted Category: ['Beauty', 'Electronics', 'Sports & Outdoors', 'Fashion & Apparel', 'Health & Personal Care', 'Tools & Home Improvement', 'Toys & Games', 'Home & Kitchen', 'Books', 'Grocery']
# Predicted Scores: [0.17881156504154205, 0.16225875914096832, 0.1543823927640915, 0.15080465376377106, 0.10110056400299072, 0.07016967982053757, 0.052385155111551285, 0.04829183220863342, 0.04344918951392174, 0.03834616020321846]
# Time taken: 3.4765 seconds
# --------------------------------------------------------------------------------
#
# Query: Can you recommend some gluten-free snacks for kids?
# Original Category: Grocery
# Predicted Category: ['Health & Personal Care', 'Fashion & Apparel', 'Grocery', 'Home & Kitchen', 'Sports & Outdoors', 'Tools & Home Improvement', 'Toys & Games', 'Books', 'Electronics', 'Beauty']
# Predicted Scores: [0.20824460685253143, 0.17473329603672028, 0.13933800160884857, 0.11804694682359695, 0.09339737892150879, 0.07382703572511673, 0.057448357343673706, 0.04842835292220116, 0.04397081211209297, 0.0425652451813221]
# Time taken: 4.7952 seconds
# --------------------------------------------------------------------------------
#
# Query: I need keto-friendly ingredients for baking at home.
# Original Category: Grocery
# Predicted Category: ['Home & Kitchen', 'Health & Personal Care', 'Grocery', 'Fashion & Apparel', 'Sports & Outdoors', 'Books', 'Toys & Games', 'Beauty', 'Electronics', 'Tools & Home Improvement']
# Predicted Scores: [0.2992772161960602, 0.16430127620697021, 0.14923551678657532, 0.07948486506938934, 0.0722552016377449, 0.0569823682308197, 0.04857106879353523, 0.04643084108829498, 0.042197294533252716, 0.04126432538032532]
# Time taken: 3.5542 seconds
# --------------------------------------------------------------------------------
#
# Query: What’s the best organic coffee for brewing at home?
# Original Category: Grocery
# Predicted Category: ['Home & Kitchen', 'Health & Personal Care', 'Fashion & Apparel', 'Tools & Home Improvement', 'Toys & Games', 'Grocery', 'Sports & Outdoors', 'Books', 'Electronics', 'Beauty']
# Predicted Scores: [0.20548288524150848, 0.15154069662094116, 0.13295698165893555, 0.09599874168634415, 0.09136764705181122, 0.08130957186222076, 0.080573670566082, 0.06652246415615082, 0.05807403475046158, 0.03617332503199577]
# Time taken: 3.6586 seconds
# --------------------------------------------------------------------------------
#
# Query: What are some good dairy-free milk alternatives?
# Original Category: Grocery
# Predicted Category: ['Health & Personal Care', 'Home & Kitchen', 'Grocery', 'Fashion & Apparel', 'Tools & Home Improvement', 'Books', 'Sports & Outdoors', 'Toys & Games', 'Beauty', 'Electronics']
# Predicted Scores: [0.19876423478126526, 0.16229303181171417, 0.1593070775270462, 0.09289870411157608, 0.08224546164274216, 0.07238724827766418, 0.06587585806846619, 0.06156821548938751, 0.05571965500712395, 0.0489405132830143]
# Time taken: 4.4242 seconds
# --------------------------------------------------------------------------------
#
# Average Time per Query: 4.1196 seconds
# Top-1 Accuracy: 0.5750
# Top-3 Accuracy: 0.8250
# Precision: 0.5367, Recall: 0.5750, F1-Score: 0.5403
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# [0.575, 33, 0.5366666666666667, 0.575, 0.5403174603174603]
